# %%
# importing necessary modules.
import requests
import json
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import config9 as cfg

# %%
# saving a postgress password and database name to variables to access postgres sql optimal portfolio database.
postgress_password =cfg.password
database_name = 'optimal_portfolio19'

# %%
# importing csv that contains the stock ticker symbols and names of the S&P 500.
sandp_df = pd.read_csv('../Resources/tickers_SandP_500.csv')

# %%
# creating empty list.
ticker_symbols = []

# looping through above csv and appending stock ticker symbols to the empty list.
for ticker in sandp_df['Ticker']:
    ticker_symbols.append(ticker)


# creating empty list.
names = []  

# looping through csv and appending names to the empty list.
for name in sandp_df['Name']:
    names.append(name)

# %%
# creating/initializing an empty pandas dataframe.
dataframe2 = pd.DataFrame()

# creating loop that goes through the ticker_symbols and names lists created above.
for (ticker, name) in zip(ticker_symbols, names):
    
    # creating a for loop that goes through the last two entry's value of the json dictionaries from financialmodelingprep.    
    for i in range(0,2):
        
        # setting up try and except statement to avoid lack of financialmodelingprep json data to ticker_symbol list.         
        try:
            
            # obtaining the json data for financial ratios from financialmodelingprep.          
            response = requests.get(f'https://financialmodelingprep.com/api/v3/financial-ratios/{ticker}').json()
            
            print(f'Processing:{ticker} {name}')
            
            # creating empty list named columns.             
            columns = []
            
            # appending 'symbol' to columns list.                
            columns.append('symbol')
            
            # appending 'name' to columns list.            
            columns.append('name')
        
            # appending 'date' to columns list.         
            columns.append('date')
            
            # creating empty list named data.            
            data = []

            # creating another try except statement to avoid pitfalls.                
            try:

                # appending symbol to data list.
                data.append(response['symbol'])

                # appending company name to data list.
                data.append(name)

                # appending date to data list.
                data.append(response['ratios'][i]['date'])

                # saving financial ratio dicionary to variable.
                keys = response['ratios'][i]

                # looping through finanial ratio keys.                   
                for key in keys:

                    # avoiding date key.                       
                    if key != 'date':

                        # looping through finanial ratio dictionary.                            
                        for x in keys[key]:

                            #  appending financial ratio dict keys to columns list.                                
                            columns.append(x)

                            # filtering financial ratio values that are blank.                 
                            if keys[key][x] == '':

                                # appending 0 in the spot of nothing to the data list.                                     
                                data.append(0)

                            # continuing the filtering process, but with some values.         
                            else:

                                # appending those financial ratio values to data list.                                 
                                data.append(float(keys[key][x]))

                # creating a connection and obtaining financial growth statistics from financialmodelingprep.
                response2 = requests.get(f'https://financialmodelingprep.com/api/v3/financial-statement-growth/{ticker}').json()

                # saving financial growth dict to variable.                  
                keys2 = response2['growth'][i]

                # creating for loop to go through financial grow. 
                for key in keys2:

                    # avoiding the date key.                       
                    if key != 'date':

                        # appending the financial growth keys to columns list.                            
                        columns.append(key)

                        # filtering financial growth values that have nan values.
                        if keys2[key] == '':

                            # replacing nan values with 0.                                 
                            data.append(0)

                        # filtering financial growth values that are not nan.
                        else:

                            # appending those financial growth values to the data list.        
                            data.append(float(keys2[key]))

                # creating a pandas dataframe based on the data and column lists developed through the above process.
                dataframe = pd.DataFrame([data], columns=columns)

                # appending the dataframe to the empty dataframe created at the very top.
                dataframe2 = dataframe2.append(dataframe)

            # finishing try except statement.
            except:

                # telling program to move on and ignore pitfall.                    
                pass

        # finishing the other try except statement.        
        except:

             # telling program to move on and ignore pitfall.
            pass

# grouping completed dataframe by symbol and name and finding the average of the columns, because used multiple dates.
dataframe2 = dataframe2.groupby(['symbol', 'name']).mean()

# viewing dataframe.
dataframe2
# Out:
# Processing:A Agilent Technologies, Inc.
# Processing:A Agilent Technologies, Inc.
# Processing:AAL American Airlines Group, Inc.
# Processing:AAL American Airlines Group, Inc.
# Processing:AAP Advance Auto Parts, Inc.
# Processing:AAP Advance Auto Parts, Inc.
# Processing:AAPL Apple, Inc.
# Processing:AAPL Apple, Inc.
# Processing:ABBV AbbVie, Inc.
# Processing:ABBV AbbVie, Inc.
# Processing:ABC AmerisourceBergen Corp.
# Processing:ABC AmerisourceBergen Corp.
# Processing:ABMD ABIOMED, Inc.
# Processing:ABMD ABIOMED, Inc.
# Processing:ABT Abbott Laboratories
# Processing:ABT Abbott Laboratories
# Processing:ACN Accenture Plc
# Processing:ACN Accenture Plc
# Processing:ADBE Adobe, Inc.
# Processing:ADBE Adobe, Inc.
# Processing:ADI Analog Devices, Inc.
# Processing:ADI Analog Devices, Inc.
# Processing:ADM Archer-Daniels-Midland Co.
# Processing:ADM Archer-Daniels-Midland Co.
# Processing:ADP Automatic Data Processing, Inc.
# Processing:ADP Automatic Data Processing, Inc.
# Processing:ADS Alliance Data Systems Corp.
# Processing:ADS Alliance Data Systems Corp.
# Processing:ADSK Autodesk, Inc.
# Processing:ADSK Autodesk, Inc.
# Processing:AEE Ameren Corp.
# Processing:AEE Ameren Corp.
# Processing:AEP American Electric Power Co., Inc.
# Processing:AEP American Electric Power Co., Inc.
# Processing:AES The AES Corp.
# Processing:AES The AES Corp.
# Processing:AFL Aflac, Inc.
# Processing:AFL Aflac, Inc.
# Processing:AGN Allergan Plc
# Processing:AGN Allergan Plc
# Processing:AIG American International Group, Inc.
# Processing:AIG American International Group, Inc.
# Processing:AIV Apartment Investment & Management Co.
# Processing:AIV Apartment Investment & Management Co.
# Processing:AIZ Assurant, Inc.
# Processing:AIZ Assurant, Inc.
# Processing:AJG Arthur J. Gallagher & Co.
# Processing:AJG Arthur J. Gallagher & Co.
# Processing:AKAM Akamai Technologies, Inc.
# Processing:AKAM Akamai Technologies, Inc.
# Processing:ALB Albemarle Corp.
# Processing:ALB Albemarle Corp.
# Processing:ALGN Align Technology, Inc.
# Processing:ALGN Align Technology, Inc.
# Processing:ALK Alaska Air Group, Inc.
# Processing:ALK Alaska Air Group, Inc.
# Processing:ALL The Allstate Corp.
# Processing:ALL The Allstate Corp.
# Processing:ALLE Allegion Plc
# Processing:ALLE Allegion Plc
# Processing:ALXN Alexion Pharmaceuticals, Inc.
# Processing:ALXN Alexion Pharmaceuticals, Inc.
# Processing:AMAT Applied Materials, Inc.
# Processing:AMAT Applied Materials, Inc.
# Processing:AMCR Amcor Plc
# Processing:AMCR Amcor Plc
# Processing:AMD Advanced Micro Devices, Inc.
# Processing:AMD Advanced Micro Devices, Inc.
# Processing:AME AMETEK, Inc.
# Processing:AME AMETEK, Inc.
# Processing:AMG Affiliated Managers Group, Inc.
# Processing:AMG Affiliated Managers Group, Inc.
# Processing:AMGN Amgen, Inc.
# Processing:AMGN Amgen, Inc.
# Processing:AMP Ameriprise Financial, Inc.
# Processing:AMP Ameriprise Financial, Inc.
# Processing:AMT American Tower Corp.
# Processing:AMT American Tower Corp.
# Processing:AMZN Amazon.com, Inc.
# Processing:AMZN Amazon.com, Inc.
# Processing:ANET Arista Networks, Inc.
# Processing:ANET Arista Networks, Inc.
# Processing:ANSS ANSYS, Inc.
# Processing:ANSS ANSYS, Inc.
# Processing:ANTM Anthem, Inc.
# Processing:ANTM Anthem, Inc.
# Processing:AON Aon Plc
# Processing:AON Aon Plc
# Processing:AOS A. O. Smith Corp.
# Processing:AOS A. O. Smith Corp.
# Processing:APA Apache Corp.
# Processing:APA Apache Corp.
# Processing:APD Air Products & Chemicals, Inc.
# Processing:APD Air Products & Chemicals, Inc.
# Processing:APH Amphenol Corp.
# Processing:APH Amphenol Corp.
# Processing:APTV Aptiv Plc
# Processing:APTV Aptiv Plc
# Processing:ARE Alexandria Real Estate Equities, Inc.
# Processing:ARE Alexandria Real Estate Equities, Inc.
# Processing:ARNC Arconic, Inc.
# Processing:ARNC Arconic, Inc.
# Processing:ATO Atmos Energy Corp.
# Processing:ATO Atmos Energy Corp.
# Processing:ATVI Activision Blizzard, Inc.
# Processing:ATVI Activision Blizzard, Inc.
# Processing:AVB AvalonBay Communities, Inc.
# Processing:AVB AvalonBay Communities, Inc.
# Processing:AVGO Broadcom, Inc.
# Processing:AVGO Broadcom, Inc.
# Processing:AVY Avery Dennison Corp.
# Processing:AVY Avery Dennison Corp.
# Processing:AWK American Water Works Co., Inc.
# Processing:AWK American Water Works Co., Inc.
# Processing:AXP American Express Co.
# Processing:AXP American Express Co.
# Processing:AZO AutoZone, Inc.
# Processing:AZO AutoZone, Inc.
# Processing:BA The Boeing Co.
# Processing:BA The Boeing Co.
# Processing:BAC Bank of America Corp.
# Processing:BAC Bank of America Corp.
# Processing:BAX Baxter International, Inc.
# Processing:BAX Baxter International, Inc.
# Processing:BBT BB&T Corp.
# Processing:BBT BB&T Corp.
# Processing:BBY Best Buy Co., Inc.
# Processing:BBY Best Buy Co., Inc.
# Processing:BDX Becton, Dickinson & Co.
# Processing:BDX Becton, Dickinson & Co.
# Processing:BEN Franklin Resources, Inc.
# Processing:BEN Franklin Resources, Inc.
# Processing:BF.B Brown-Forman Corp.
# Processing:BF.B Brown-Forman Corp.
# Processing:BHGE Baker Hughes, a GE Co.
# Processing:BHGE Baker Hughes, a GE Co.
# Processing:BIIB Biogen, Inc.
# Processing:BIIB Biogen, Inc.
# Processing:BK The Bank of New York Mellon Corp.
# Processing:BK The Bank of New York Mellon Corp.
# Processing:BKNG Booking Holdings, Inc.
# Processing:BKNG Booking Holdings, Inc.
# Processing:BLK BlackRock, Inc.
# Processing:BLK BlackRock, Inc.
# Processing:BLL Ball Corp.
# Processing:BLL Ball Corp.
# Processing:BMY Bristol-Myers Squibb Co.
# Processing:BMY Bristol-Myers Squibb Co.
# Processing:BR Broadridge Financial Solutions, Inc.
# Processing:BR Broadridge Financial Solutions, Inc.
# Processing:BRK.B Berkshire Hathaway, Inc.
# Processing:BRK.B Berkshire Hathaway, Inc.
# Processing:BSX Boston Scientific Corp.
# Processing:BSX Boston Scientific Corp.
# Processing:BWA BorgWarner, Inc.
# Processing:BWA BorgWarner, Inc.
# Processing:BXP Boston Properties, Inc.
# Processing:BXP Boston Properties, Inc.
# Processing:C Citigroup, Inc.
# Processing:C Citigroup, Inc.
# Processing:CAG Conagra Brands, Inc.
# Processing:CAG Conagra Brands, Inc.
# Processing:CAH Cardinal Health, Inc.
# Processing:CAH Cardinal Health, Inc.
# Processing:CAT Caterpillar, Inc.
# Processing:CAT Caterpillar, Inc.
# Processing:CB Chubb Ltd.
# Processing:CB Chubb Ltd.
# Processing:CBOE Cboe Global Markets, Inc.
# Processing:CBOE Cboe Global Markets, Inc.
# Processing:CBRE CBRE Group, Inc.
# Processing:CBRE CBRE Group, Inc.
# Processing:CBS ViacomCBS, Inc.
# Processing:CBS ViacomCBS, Inc.
# Processing:CCI Crown Castle International Corp.
# Processing:CCI Crown Castle International Corp.
# Processing:CCL Carnival Corp.
# Processing:CCL Carnival Corp.
# Processing:CDNS Cadence Design Systems, Inc.
# Processing:CDNS Cadence Design Systems, Inc.
# Processing:CDW CDW Corp.
# Processing:CDW CDW Corp.
# Processing:CE Celanese Corp.
# Processing:CE Celanese Corp.
# Processing:CELG Celgene Corporation
# Processing:CELG Celgene Corporation
# Processing:CERN Cerner Corp.
# Processing:CERN Cerner Corp.
# Processing:CF CF Industries Holdings, Inc.
# Processing:CF CF Industries Holdings, Inc.
# Processing:CFG Citizens Financial Group, Inc. (Rhode Island)
# Processing:CFG Citizens Financial Group, Inc. (Rhode Island)
# Processing:CHD Church & Dwight Co., Inc.
# Processing:CHD Church & Dwight Co., Inc.
# Processing:CHRW C.H. Robinson Worldwide, Inc.
# Processing:CHRW C.H. Robinson Worldwide, Inc.
# Processing:CHTR Charter Communications, Inc.
# Processing:CHTR Charter Communications, Inc.
# Processing:CI Cigna Corp.
# Processing:CI Cigna Corp.
# Processing:CINF Cincinnati Financial Corp.
# Processing:CINF Cincinnati Financial Corp.
# Processing:CL Colgate-Palmolive Co.
# Processing:CL Colgate-Palmolive Co.
# Processing:CLX The Clorox Co.
# Processing:CLX The Clorox Co.
# Processing:CMA Comerica, Inc.
# Processing:CMA Comerica, Inc.
# Processing:CMCSA Comcast Corp.
# Processing:CMCSA Comcast Corp.
# Processing:CME CME Group, Inc.
# Processing:CME CME Group, Inc.
# Processing:CMG Chipotle Mexican Grill, Inc.
# Processing:CMG Chipotle Mexican Grill, Inc.
# Processing:CMI Cummins, Inc.
# Processing:CMI Cummins, Inc.
# Processing:CMS CMS Energy Corp.
# Processing:CMS CMS Energy Corp.
# Processing:CNC Centene Corp.
# Processing:CNC Centene Corp.
# Processing:CNP CenterPoint Energy, Inc.
# Processing:CNP CenterPoint Energy, Inc.
# Processing:COF Capital One Financial Corp.
# Processing:COF Capital One Financial Corp.
# Processing:COG Cabot Oil & Gas Corp.
# Processing:COG Cabot Oil & Gas Corp.
# Processing:COO The Cooper Cos., Inc.
# Processing:COO The Cooper Cos., Inc.
# Processing:COP ConocoPhillips
# Processing:COP ConocoPhillips
# Processing:COST Costco Wholesale Corp.
# Processing:COST Costco Wholesale Corp.
# Processing:COTY Coty, Inc.
# Processing:COTY Coty, Inc.
# Processing:CPB Campbell Soup Co.
# Processing:CPB Campbell Soup Co.
# Processing:CPRI Capri Holdings Ltd.
# Processing:CPRI Capri Holdings Ltd.
# Processing:CPRT Copart, Inc.
# Processing:CPRT Copart, Inc.
# Processing:CRM salesforce.com, inc.
# Processing:CRM salesforce.com, inc.
# Processing:CSCO Cisco Systems, Inc.
# Processing:CSCO Cisco Systems, Inc.
# Processing:CSX CSX Corp.
# Processing:CSX CSX Corp.
# Processing:CTAS Cintas Corp.
# Processing:CTAS Cintas Corp.
# Processing:CTL CenturyLink, Inc.
# Processing:CTL CenturyLink, Inc.
# Processing:CTSH Cognizant Technology Solutions Corp.
# Processing:CTSH Cognizant Technology Solutions Corp.
# Processing:CTVA Corteva, Inc.
# Processing:CTVA Corteva, Inc.
# Processing:CTXS Citrix Systems, Inc.
# Processing:CTXS Citrix Systems, Inc.
# Processing:CVS CVS Health Corp.
# Processing:CVS CVS Health Corp.
# Processing:CVX Chevron Corp.
# Processing:CVX Chevron Corp.
# Processing:CXO Concho Resources, Inc.
# Processing:CXO Concho Resources, Inc.
# Processing:D Dominion Energy, Inc.
# Processing:D Dominion Energy, Inc.
# Processing:DAL Delta Air Lines, Inc.
# Processing:DAL Delta Air Lines, Inc.
# Processing:DD DuPont de Nemours, Inc.
# Processing:DD DuPont de Nemours, Inc.
# Processing:DE Deere & Co.
# Processing:DE Deere & Co.
# Processing:DFS Discover Financial Services
# Processing:DFS Discover Financial Services
# Processing:DG Dollar General Corp.
# Processing:DG Dollar General Corp.
# Processing:DGX Quest Diagnostics, Inc.
# Processing:DGX Quest Diagnostics, Inc.
# Processing:DHI D.R. Horton, Inc.
# Processing:DHI D.R. Horton, Inc.
# Processing:DHR Danaher Corp.
# Processing:DHR Danaher Corp.
# Processing:DIS The Walt Disney Co.
# Processing:DIS The Walt Disney Co.
# Processing:DISCA Discovery, Inc.
# Processing:DISCA Discovery, Inc.
# Processing:DISCK Discovery, Inc.
# Processing:DISCK Discovery, Inc.
# Processing:DISH DISH Network Corp.
# Processing:DISH DISH Network Corp.
# Processing:DLR Digital Realty Trust, Inc.
# Processing:DLR Digital Realty Trust, Inc.
# Processing:DLTR Dollar Tree, Inc.
# Processing:DLTR Dollar Tree, Inc.
# Processing:DOV Dover Corp.
# Processing:DOV Dover Corp.
# Processing:DOW Dow, Inc.
# Processing:DOW Dow, Inc.
# Processing:DRE Duke Realty Corp.
# Processing:DRE Duke Realty Corp.
# Processing:DRI Darden Restaurants, Inc.
# Processing:DRI Darden Restaurants, Inc.
# Processing:DTE DTE Energy Co.
# Processing:DTE DTE Energy Co.
# Processing:DUK Duke Energy Corp.
# Processing:DUK Duke Energy Corp.
# Processing:DVA DaVita, Inc.
# Processing:DVA DaVita, Inc.
# Processing:DVN Devon Energy Corp.
# Processing:DVN Devon Energy Corp.
# Processing:DXC DXC Technology Co.
# Processing:DXC DXC Technology Co.
# Processing:EA Electronic Arts, Inc.
# Processing:EA Electronic Arts, Inc.
# Processing:EBAY eBay, Inc.
# Processing:EBAY eBay, Inc.
# Processing:ECL Ecolab, Inc.
# Processing:ECL Ecolab, Inc.
# Processing:ED Consolidated Edison, Inc.
# Processing:ED Consolidated Edison, Inc.
# Processing:EFX Equifax, Inc.
# Processing:EFX Equifax, Inc.
# Processing:EIX Edison International
# Processing:EIX Edison International
# Processing:EL The Estée Lauder Companies, Inc.
# Processing:EL The Estée Lauder Companies, Inc.
# Processing:EMN Eastman Chemical Co.
# Processing:EMN Eastman Chemical Co.
# Processing:EMR Emerson Electric Co.
# Processing:EMR Emerson Electric Co.
# Processing:EOG EOG Resources, Inc.
# Processing:EOG EOG Resources, Inc.
# Processing:EQIX Equinix, Inc.
# Processing:EQIX Equinix, Inc.
# Processing:EQR Equity Residential
# Processing:EQR Equity Residential
# Processing:ES Eversource Energy
# Processing:ES Eversource Energy
# Processing:ESS Essex Property Trust, Inc.
# Processing:ESS Essex Property Trust, Inc.
# Processing:ETFC E*TRADE Financial Corp.
# Processing:ETFC E*TRADE Financial Corp.
# Processing:ETN Eaton Corp. Plc
# Processing:ETN Eaton Corp. Plc
# Processing:ETR Entergy Corp.
# Processing:ETR Entergy Corp.
# Processing:EVRG Evergy, Inc.
# Processing:EVRG Evergy, Inc.
# Processing:EW Edwards Lifesciences Corp.
# Processing:EW Edwards Lifesciences Corp.
# Processing:EXC Exelon Corp.
# Processing:EXC Exelon Corp.
# Processing:EXPD Expeditors International of Washington, Inc.
# Processing:EXPD Expeditors International of Washington, Inc.
# Processing:EXPE Expedia Group, Inc.
# Processing:EXPE Expedia Group, Inc.
# Processing:EXR Extra Space Storage, Inc.
# Processing:EXR Extra Space Storage, Inc.
# Processing:F Ford Motor Co.
# Processing:F Ford Motor Co.
# Processing:FANG Diamondback Energy, Inc.
# Processing:FANG Diamondback Energy, Inc.
# Processing:FAST Fastenal Co.
# Processing:FAST Fastenal Co.
# Processing:FB Facebook, Inc.
# Processing:FB Facebook, Inc.
# Processing:FBHS Fortune Brands Home & Security, Inc.
# Processing:FBHS Fortune Brands Home & Security, Inc.
# Processing:FCX Freeport-McMoRan, Inc.
# Processing:FCX Freeport-McMoRan, Inc.
# Processing:FDX FedEx Corp.
# Processing:FDX FedEx Corp.
# Processing:FE FirstEnergy Corp.
# Processing:FE FirstEnergy Corp.
# Processing:FFIV F5 Networks, Inc.
# Processing:FFIV F5 Networks, Inc.
# Processing:FIS Fidelity National Information Services, Inc.
# Processing:FIS Fidelity National Information Services, Inc.
# Processing:FISV Fiserv, Inc.
# Processing:FISV Fiserv, Inc.
# Processing:FITB Fifth Third Bancorp
# Processing:FITB Fifth Third Bancorp
# Processing:FLIR FLIR Systems, Inc.
# Processing:FLIR FLIR Systems, Inc.
# Processing:FLS Flowserve Corp.
# Processing:FLS Flowserve Corp.
# Processing:FLT FleetCor Technologies, Inc.
# Processing:FLT FleetCor Technologies, Inc.
# Processing:FMC FMC Corp.
# Processing:FMC FMC Corp.
# Processing:FOX Fox Corp.
# Processing:FOX Fox Corp.
# Processing:FOXA Fox Corp.
# Processing:FOXA Fox Corp.
# Processing:FRC First Republic Bank (San Francisco, California)
# Processing:FRC First Republic Bank (San Francisco, California)
# Processing:FRT Federal Realty Investment Trust
# Processing:FRT Federal Realty Investment Trust
# Processing:FTI TechnipFMC Plc
# Processing:FTI TechnipFMC Plc
# Processing:FTNT Fortinet, Inc.
# Processing:FTNT Fortinet, Inc.
# Processing:FTV Fortive Corp.
# Processing:FTV Fortive Corp.
# Processing:GD General Dynamics Corp.
# Processing:GD General Dynamics Corp.
# Processing:GE General Electric Co.
# Processing:GE General Electric Co.
# Processing:GILD Gilead Sciences, Inc.
# Processing:GILD Gilead Sciences, Inc.
# Processing:GIS General Mills, Inc.
# Processing:GIS General Mills, Inc.
# Processing:GL Globe Life, Inc.
# Processing:GL Globe Life, Inc.
# Processing:GLW Corning, Inc.
# Processing:GLW Corning, Inc.
# Processing:GM General Motors Co.
# Processing:GM General Motors Co.
# Processing:GOOG Alphabet, Inc.
# Processing:GOOG Alphabet, Inc.
# Processing:GOOGL Alphabet, Inc.
# Processing:GOOGL Alphabet, Inc.
# Processing:GPC Genuine Parts Co.
# Processing:GPC Genuine Parts Co.
# Processing:GPN Global Payments, Inc.
# Processing:GPN Global Payments, Inc.
# Processing:GPS Gap, Inc.
# Processing:GPS Gap, Inc.
# Processing:GRMN Garmin Ltd.
# Processing:GRMN Garmin Ltd.
# Processing:GS The Goldman Sachs Group, Inc.
# Processing:GS The Goldman Sachs Group, Inc.
# Processing:GWW W.W. Grainger, Inc.
# Processing:GWW W.W. Grainger, Inc.
# Processing:HAL Halliburton Co.
# Processing:HAL Halliburton Co.
# Processing:HAS Hasbro, Inc.
# Processing:HAS Hasbro, Inc.
# Processing:HBAN Huntington Bancshares, Inc.
# Processing:HBAN Huntington Bancshares, Inc.
# Processing:HBI Hanesbrands, Inc.
# Processing:HBI Hanesbrands, Inc.
# Processing:HCA HCA Healthcare, Inc.
# Processing:HCA HCA Healthcare, Inc.
# Processing:HCP Healthpeak Properties, Inc.
# Processing:HCP Healthpeak Properties, Inc.
# Processing:HD The Home Depot, Inc.
# Processing:HD The Home Depot, Inc.
# Processing:HES Hess Corp.
# Processing:HES Hess Corp.
# Processing:HFC HollyFrontier Corp.
# Processing:HFC HollyFrontier Corp.
# Processing:HIG The Hartford Financial Services Group, Inc.
# Processing:HIG The Hartford Financial Services Group, Inc.
# Processing:HII Huntington Ingalls Industries, Inc.
# Processing:HII Huntington Ingalls Industries, Inc.
# Processing:HLT Hilton Worldwide Holdings, Inc.
# Processing:HLT Hilton Worldwide Holdings, Inc.
# Processing:HOG Harley-Davidson, Inc.
# Processing:HOG Harley-Davidson, Inc.
# Processing:HOLX Hologic, Inc.
# Processing:HOLX Hologic, Inc.
# Processing:HON Honeywell International, Inc.
# Processing:HON Honeywell International, Inc.
# Processing:HP Helmerich & Payne, Inc.
# Processing:HP Helmerich & Payne, Inc.
# Processing:HPE Hewlett-Packard Enterprise Co.
# Processing:HPE Hewlett-Packard Enterprise Co.
# Processing:HPQ HP, Inc.
# Processing:HPQ HP, Inc.
# Processing:HRB H&R Block, Inc.
# Processing:HRB H&R Block, Inc.
# Processing:HRL Hormel Foods Corp.
# Processing:HRL Hormel Foods Corp.
# Processing:HSIC Henry Schein, Inc.
# Processing:HSIC Henry Schein, Inc.
# Processing:HST Host Hotels & Resorts, Inc.
# Processing:HST Host Hotels & Resorts, Inc.
# Processing:HSY The Hershey Co.
# Processing:HSY The Hershey Co.
# Processing:HUM Humana, Inc.
# Processing:HUM Humana, Inc.
# Processing:IBM International Business Machines Corp.
# Processing:IBM International Business Machines Corp.
# Processing:ICE Intercontinental Exchange, Inc.
# Processing:ICE Intercontinental Exchange, Inc.
# Processing:IDXX IDEXX Laboratories, Inc.
# Processing:IDXX IDEXX Laboratories, Inc.
# Processing:IEX IDEX Corp.
# Processing:IEX IDEX Corp.
# Processing:IFF International Flavors & Fragrances, Inc.
# Processing:IFF International Flavors & Fragrances, Inc.
# Processing:ILMN Illumina, Inc.
# Processing:ILMN Illumina, Inc.
# Processing:INCY Incyte Corp.
# Processing:INCY Incyte Corp.
# Processing:INFO IHS Markit Ltd.
# Processing:INFO IHS Markit Ltd.
# Processing:INTC Intel Corp.
# Processing:INTC Intel Corp.
# Processing:INTU Intuit, Inc.
# Processing:INTU Intuit, Inc.
# Processing:IP International Paper Co.
# Processing:IP International Paper Co.
# Processing:IPG Interpublic Group of Cos., Inc.
# Processing:IPG Interpublic Group of Cos., Inc.
# Processing:IPGP IPG Photonics Corp.
# Processing:IPGP IPG Photonics Corp.
# Processing:IQV IQVIA Holdings, Inc.
# Processing:IQV IQVIA Holdings, Inc.
# Processing:IR Ingersoll-Rand Plc
# Processing:IR Ingersoll-Rand Plc
# Processing:IRM Iron Mountain, Inc.
# Processing:IRM Iron Mountain, Inc.
# Processing:ISRG Intuitive Surgical, Inc.
# Processing:ISRG Intuitive Surgical, Inc.
# Processing:IT Gartner, Inc.
# Processing:IT Gartner, Inc.
# Processing:ITW Illinois Tool Works, Inc.
# Processing:ITW Illinois Tool Works, Inc.
# Processing:IVZ Invesco Ltd.
# Processing:IVZ Invesco Ltd.
# Processing:JBHT J.B. Hunt Transport Services, Inc.
# Processing:JBHT J.B. Hunt Transport Services, Inc.
# Processing:JCI Johnson Controls International Plc
# Processing:JCI Johnson Controls International Plc
# Processing:JEC Jacobs Engineering Group, Inc.
# Processing:JEC Jacobs Engineering Group, Inc.
# Processing:JKHY Jack Henry & Associates, Inc.
# Processing:JKHY Jack Henry & Associates, Inc.
# Processing:JNJ Johnson & Johnson
# Processing:JNJ Johnson & Johnson
# Processing:JNPR Juniper Networks, Inc.
# Processing:JNPR Juniper Networks, Inc.
# Processing:JPM JPMorgan Chase & Co.
# Processing:JPM JPMorgan Chase & Co.
# Processing:JWN Nordstrom, Inc.
# Processing:JWN Nordstrom, Inc.
# Processing:K Kellogg Co.
# Processing:K Kellogg Co.
# Processing:KEY KeyCorp
# Processing:KEY KeyCorp
# Processing:KEYS Keysight Technologies, Inc.
# Processing:KEYS Keysight Technologies, Inc.
# Processing:KHC The Kraft Heinz Co.
# Processing:KHC The Kraft Heinz Co.
# Processing:KIM Kimco Realty Corp.
# Processing:KIM Kimco Realty Corp.
# Processing:KLAC KLA Corp.
# Processing:KLAC KLA Corp.
# Processing:KMB Kimberly-Clark Corp.
# Processing:KMB Kimberly-Clark Corp.
# Processing:KMI Kinder Morgan, Inc.
# Processing:KMI Kinder Morgan, Inc.
# Processing:KMX CarMax, Inc.
# Processing:KMX CarMax, Inc.
# Processing:KO The Coca-Cola Co.
# Processing:KO The Coca-Cola Co.
# Processing:KR The Kroger Co.
# Processing:KR The Kroger Co.
# Processing:KSS Kohl's Corp.
# Processing:KSS Kohl's Corp.
# Processing:KSU Kansas City Southern
# Processing:KSU Kansas City Southern
# Processing:L Loews Corp.
# Processing:L Loews Corp.
# Processing:LB L Brands, Inc.
# Processing:LB L Brands, Inc.
# Processing:LDOS Leidos Holdings, Inc.
# Processing:LDOS Leidos Holdings, Inc.
# Processing:LEG Leggett & Platt, Inc.
# Processing:LEG Leggett & Platt, Inc.
# Processing:LEN Lennar Corp.
# Processing:LEN Lennar Corp.
# Processing:LH Laboratory Corp. of America Holdings
# Processing:LH Laboratory Corp. of America Holdings
# Processing:LHX L3Harris Technologies, Inc.
# Processing:LHX L3Harris Technologies, Inc.
# Processing:LIN Linde Plc
# Processing:LIN Linde Plc
# Processing:LKQ LKQ Corp.
# Processing:LKQ LKQ Corp.
# Processing:LLY Eli Lilly & Co.
# Processing:LLY Eli Lilly & Co.
# Processing:LMT Lockheed Martin Corp.
# Processing:LMT Lockheed Martin Corp.
# Processing:LNC Lincoln National Corp.
# Processing:LNC Lincoln National Corp.
# Processing:LNT Alliant Energy Corp.
# Processing:LNT Alliant Energy Corp.
# Processing:LOW Lowe's Cos., Inc.
# Processing:LOW Lowe's Cos., Inc.
# Processing:LRCX Lam Research Corp.
# Processing:LRCX Lam Research Corp.
# Processing:LUV Southwest Airlines Co.
# Processing:LUV Southwest Airlines Co.
# Processing:LVS Las Vegas Sands Corp.
# Processing:LVS Las Vegas Sands Corp.
# Processing:LW Lamb Weston Holdings, Inc.
# Processing:LW Lamb Weston Holdings, Inc.
# Processing:LYB LyondellBasell Industries NV
# Processing:LYB LyondellBasell Industries NV
# Processing:M Macy's, Inc.
# Processing:M Macy's, Inc.
# Processing:MA Mastercard, Inc.
# Processing:MA Mastercard, Inc.
# Processing:MAA Mid-America Apartment Communities, Inc.
# Processing:MAA Mid-America Apartment Communities, Inc.
# Processing:MAC Macerich Co.
# Processing:MAC Macerich Co.
# Processing:MAR Marriott International, Inc.
# Processing:MAR Marriott International, Inc.
# Processing:MAS Masco Corp.
# Processing:MAS Masco Corp.
# Processing:MCD McDonald's Corp.
# Processing:MCD McDonald's Corp.
# Processing:MCHP Microchip Technology, Inc.
# Processing:MCHP Microchip Technology, Inc.
# Processing:MCK McKesson Corp.
# Processing:MCK McKesson Corp.
# Processing:MCO Moody's Corp.
# Processing:MCO Moody's Corp.
# Processing:MDLZ Mondelez International, Inc.
# Processing:MDLZ Mondelez International, Inc.
# Processing:MDT Medtronic Plc
# Processing:MDT Medtronic Plc
# Processing:MET MetLife, Inc.
# Processing:MET MetLife, Inc.
# Processing:MGM MGM Resorts International
# Processing:MGM MGM Resorts International
# Processing:MHK Mohawk Industries, Inc.
# Processing:MHK Mohawk Industries, Inc.
# Processing:MKC McCormick & Co., Inc.
# Processing:MKC McCormick & Co., Inc.
# Processing:MKTX MarketAxess Holdings, Inc.
# Processing:MKTX MarketAxess Holdings, Inc.
# Processing:MLM Martin Marietta Materials, Inc.
# Processing:MLM Martin Marietta Materials, Inc.
# Processing:MMC Marsh & McLennan Cos., Inc.
# Processing:MMC Marsh & McLennan Cos., Inc.
# Processing:MMM 3M Co.
# Processing:MMM 3M Co.
# Processing:MNST Monster Beverage Corp.
# Processing:MNST Monster Beverage Corp.
# Processing:MO Altria Group, Inc.
# Processing:MO Altria Group, Inc.
# Processing:MOS The Mosaic Co.
# Processing:MOS The Mosaic Co.
# Processing:MPC Marathon Petroleum Corp.
# Processing:MPC Marathon Petroleum Corp.
# Processing:MRK Merck & Co., Inc.
# Processing:MRK Merck & Co., Inc.
# Processing:MRO Marathon Oil Corp.
# Processing:MRO Marathon Oil Corp.
# Processing:MS Morgan Stanley
# Processing:MS Morgan Stanley
# Processing:MSCI MSCI, Inc.
# Processing:MSCI MSCI, Inc.
# Processing:MSFT Microsoft Corp.
# Processing:MSFT Microsoft Corp.
# Processing:MSI Motorola Solutions, Inc.
# Processing:MSI Motorola Solutions, Inc.
# Processing:MTB M&T Bank Corp.
# Processing:MTB M&T Bank Corp.
# Processing:MTD Mettler-Toledo International, Inc.
# Processing:MTD Mettler-Toledo International, Inc.
# Processing:MU Micron Technology, Inc.
# Processing:MU Micron Technology, Inc.
# Processing:MXIM Maxim Integrated Products, Inc.
# Processing:MXIM Maxim Integrated Products, Inc.
# Processing:MYL Mylan NV
# Processing:MYL Mylan NV
# Processing:NBL Noble Energy, Inc.
# Processing:NBL Noble Energy, Inc.
# Processing:NCLH Norwegian Cruise Line Holdings Ltd.
# Processing:NCLH Norwegian Cruise Line Holdings Ltd.
# Processing:NDAQ Nasdaq, Inc.
# Processing:NDAQ Nasdaq, Inc.
# Processing:NEE NextEra Energy, Inc.
# Processing:NEE NextEra Energy, Inc.
# Processing:NEM Newmont Corp.
# Processing:NEM Newmont Corp.
# Processing:NFLX Netflix, Inc.
# Processing:NFLX Netflix, Inc.
# Processing:NI NiSource, Inc.
# Processing:NI NiSource, Inc.
# Processing:NKE NIKE, Inc.
# Processing:NKE NIKE, Inc.
# Processing:NLSN Nielsen Holdings Plc
# Processing:NLSN Nielsen Holdings Plc
# Processing:NOC Northrop Grumman Corp.
# Processing:NOC Northrop Grumman Corp.
# Processing:NOV National Oilwell Varco, Inc.
# Processing:NOV National Oilwell Varco, Inc.
# Processing:NRG NRG Energy, Inc.
# Processing:NRG NRG Energy, Inc.
# Processing:NSC Norfolk Southern Corp.
# Processing:NSC Norfolk Southern Corp.
# Processing:NTAP NetApp, Inc.
# Processing:NTAP NetApp, Inc.
# Processing:NTRS Northern Trust Corp.
# Processing:NTRS Northern Trust Corp.
# Processing:NUE Nucor Corp.
# Processing:NUE Nucor Corp.
# Processing:NVDA NVIDIA Corp.
# Processing:NVDA NVIDIA Corp.
# Processing:NVR NVR, Inc.
# Processing:NVR NVR, Inc.
# Processing:NWL Newell Brands, Inc.
# Processing:NWL Newell Brands, Inc.
# Processing:NWS News Corp.
# Processing:NWS News Corp.
# Processing:NWSA News Corp.
# Processing:NWSA News Corp.
# Processing:O Realty Income Corp.
# Processing:O Realty Income Corp.
# Processing:OKE ONEOK, Inc.
# Processing:OKE ONEOK, Inc.
# Processing:OMC Omnicom Group, Inc.
# Processing:OMC Omnicom Group, Inc.
# Processing:ORCL Oracle Corp.
# Processing:ORCL Oracle Corp.
# Processing:ORLY O'Reilly Automotive, Inc.
# Processing:ORLY O'Reilly Automotive, Inc.
# Processing:OXY Occidental Petroleum Corp.
# Processing:OXY Occidental Petroleum Corp.
# Processing:PAYX Paychex, Inc.
# Processing:PAYX Paychex, Inc.
# Processing:PBCT People's United Financial, Inc.
# Processing:PBCT People's United Financial, Inc.
# Processing:PCAR PACCAR, Inc.
# Processing:PCAR PACCAR, Inc.
# Processing:PEG Public Service Enterprise Group, Inc.
# Processing:PEG Public Service Enterprise Group, Inc.
# Processing:PEP PepsiCo, Inc.
# Processing:PEP PepsiCo, Inc.
# Processing:PFE Pfizer Inc.
# Processing:PFE Pfizer Inc.
# Processing:PFG Principal Financial Group, Inc.
# Processing:PFG Principal Financial Group, Inc.
# Processing:PG Procter & Gamble Co.
# Processing:PG Procter & Gamble Co.
# Processing:PGR Progressive Corp.
# Processing:PGR Progressive Corp.
# Processing:PH Parker-Hannifin Corp.
# Processing:PH Parker-Hannifin Corp.
# Processing:PHM PulteGroup, Inc.
# Processing:PHM PulteGroup, Inc.
# Processing:PKG Packaging Corporation of America
# Processing:PKG Packaging Corporation of America
# Processing:PKI PerkinElmer, Inc. (United States)
# Processing:PKI PerkinElmer, Inc. (United States)
# Processing:PLD Prologis, Inc.
# Processing:PLD Prologis, Inc.
# Processing:PM Philip Morris International, Inc.
# Processing:PM Philip Morris International, Inc.
# Processing:PNC The PNC Financial Services Group, Inc.
# Processing:PNC The PNC Financial Services Group, Inc.
# Processing:PNR Pentair Plc
# Processing:PNR Pentair Plc
# Processing:PNW Pinnacle West Capital Corp.
# Processing:PNW Pinnacle West Capital Corp.
# Processing:PPG PPG Industries, Inc.
# Processing:PPG PPG Industries, Inc.
# Processing:PPL PPL Corp.
# Processing:PPL PPL Corp.
# Processing:PRGO Perrigo Co. Plc
# Processing:PRGO Perrigo Co. Plc
# Processing:PRU Prudential Financial, Inc.
# Processing:PRU Prudential Financial, Inc.
# Processing:PSA Public Storage
# Processing:PSA Public Storage
# Processing:PSX Phillips 66
# Processing:PSX Phillips 66
# Processing:PVH PVH Corp.
# Processing:PVH PVH Corp.
# Processing:PWR Quanta Services, Inc.
# Processing:PWR Quanta Services, Inc.
# Processing:PXD Pioneer Natural Resources Co.
# Processing:PXD Pioneer Natural Resources Co.
# Processing:PYPL PayPal Holdings, Inc.
# Processing:PYPL PayPal Holdings, Inc.
# Processing:QCOM QUALCOMM, Inc.
# Processing:QCOM QUALCOMM, Inc.
# Processing:QRVO Qorvo, Inc.
# Processing:QRVO Qorvo, Inc.
# Processing:RCL Royal Caribbean Cruises Ltd.
# Processing:RCL Royal Caribbean Cruises Ltd.
# Processing:RE Everest Re Group Ltd.
# Processing:RE Everest Re Group Ltd.
# Processing:REG Regency Centers Corp.
# Processing:REG Regency Centers Corp.
# Processing:REGN Regeneron Pharmaceuticals, Inc.
# Processing:REGN Regeneron Pharmaceuticals, Inc.
# Processing:RF Regions Financial Corp.
# Processing:RF Regions Financial Corp.
# Processing:RHI Robert Half International, Inc.
# Processing:RHI Robert Half International, Inc.
# Processing:RJF Raymond James Financial, Inc.
# Processing:RJF Raymond James Financial, Inc.
# Processing:RL Ralph Lauren Corp.
# Processing:RL Ralph Lauren Corp.
# Processing:RMD ResMed, Inc.
# Processing:RMD ResMed, Inc.
# Processing:ROK Rockwell Automation, Inc.
# Processing:ROK Rockwell Automation, Inc.
# Processing:ROL Rollins, Inc.
# Processing:ROL Rollins, Inc.
# Processing:ROP Roper Technologies, Inc.
# Processing:ROP Roper Technologies, Inc.
# Processing:ROST Ross Stores, Inc.
# Processing:ROST Ross Stores, Inc.
# Processing:RSG Republic Services, Inc.
# Processing:RSG Republic Services, Inc.
# Processing:RTN Raytheon Co.
# Processing:RTN Raytheon Co.
# Processing:SBAC SBA Communications Corp.
# Processing:SBAC SBA Communications Corp.
# Processing:SBUX Starbucks Corp.
# Processing:SBUX Starbucks Corp.
# Processing:SCHW The Charles Schwab Corp.
# Processing:SCHW The Charles Schwab Corp.
# Processing:SEE Sealed Air Corp.
# Processing:SEE Sealed Air Corp.
# Processing:SHW The Sherwin-Williams Co.
# Processing:SHW The Sherwin-Williams Co.
# Processing:SIVB SVB Financial Group
# Processing:SIVB SVB Financial Group
# Processing:SJM The J. M. Smucker Co.
# Processing:SJM The J. M. Smucker Co.
# Processing:SLB Schlumberger NV
# Processing:SLB Schlumberger NV
# Processing:SLG SL Green Realty Corp.
# Processing:SLG SL Green Realty Corp.
# Processing:SNA Snap-On, Inc.
# Processing:SNA Snap-On, Inc.
# Processing:SNPS Synopsys, Inc.
# Processing:SNPS Synopsys, Inc.
# Processing:SO The Southern Co.
# Processing:SO The Southern Co.
# Processing:SPG Simon Property Group, Inc.
# Processing:SPG Simon Property Group, Inc.
# Processing:SPGI S&P Global, Inc.
# Processing:SPGI S&P Global, Inc.
# Processing:SRE Sempra Energy
# Processing:SRE Sempra Energy
# Processing:STI SunTrust Banks, Inc.
# Processing:STI SunTrust Banks, Inc.
# Processing:STT State Street Corp.
# Processing:STT State Street Corp.
# Processing:STX Seagate Technology Plc
# Processing:STX Seagate Technology Plc
# Processing:STZ Constellation Brands, Inc.
# Processing:STZ Constellation Brands, Inc.
# Processing:SWK Stanley Black & Decker, Inc.
# Processing:SWK Stanley Black & Decker, Inc.
# Processing:SWKS Skyworks Solutions, Inc.
# Processing:SWKS Skyworks Solutions, Inc.
# Processing:SYF Synchrony Financial
# Processing:SYF Synchrony Financial
# Processing:SYK Stryker Corp.
# Processing:SYK Stryker Corp.
# Processing:SYMC Symantec Corp.
# Processing:SYMC Symantec Corp.
# Processing:SYY Sysco Corp.
# Processing:SYY Sysco Corp.
# Processing:T AT&T, Inc.
# Processing:T AT&T, Inc.
# Processing:TAP Molson Coors Beverage Co.
# Processing:TAP Molson Coors Beverage Co.
# Processing:TDG TransDigm Group, Inc.
# Processing:TDG TransDigm Group, Inc.
# Processing:TEL TE Connectivity Ltd.
# Processing:TEL TE Connectivity Ltd.
# Processing:TFX Teleflex, Inc.
# Processing:TFX Teleflex, Inc.
# Processing:TGT Target Corp.
# Processing:TGT Target Corp.
# Processing:TIF Tiffany & Co.
# Processing:TIF Tiffany & Co.
# Processing:TJX The TJX Cos., Inc.
# Processing:TJX The TJX Cos., Inc.
# Processing:TMO Thermo Fisher Scientific, Inc.
# Processing:TMO Thermo Fisher Scientific, Inc.
# Processing:TMUS T-Mobile US, Inc.
# Processing:TMUS T-Mobile US, Inc.
# Processing:TPR Tapestry, Inc.
# Processing:TPR Tapestry, Inc.
# Processing:TRIP TripAdvisor, Inc.
# Processing:TRIP TripAdvisor, Inc.
# Processing:TROW T. Rowe Price Group, Inc.
# Processing:TROW T. Rowe Price Group, Inc.
# Processing:TRV The Travelers Cos., Inc.
# Processing:TRV The Travelers Cos., Inc.
# Processing:TSCO Tractor Supply Co.
# Processing:TSCO Tractor Supply Co.
# Processing:TSN Tyson Foods, Inc.
# Processing:TSN Tyson Foods, Inc.
# Processing:TTWO Take-Two Interactive Software, Inc.
# Processing:TTWO Take-Two Interactive Software, Inc.
# Processing:TWTR Twitter, Inc.
# Processing:TWTR Twitter, Inc.
# Processing:TXN Texas Instruments Incorporated
# Processing:TXN Texas Instruments Incorporated
# Processing:TXT Textron, Inc.
# Processing:TXT Textron, Inc.
# Processing:UA Under Armour, Inc.
# Processing:UA Under Armour, Inc.
# Processing:UAA Under Armour, Inc.
# Processing:UAA Under Armour, Inc.
# Processing:UAL United Airlines Holdings, Inc.
# Processing:UAL United Airlines Holdings, Inc.
# Processing:UDR UDR, Inc.
# Processing:UDR UDR, Inc.
# Processing:UHS Universal Health Services, Inc.
# Processing:UHS Universal Health Services, Inc.
# Processing:ULTA Ulta Beauty, Inc.
# Processing:ULTA Ulta Beauty, Inc.
# Processing:UNH UnitedHealth Group, Inc.
# Processing:UNH UnitedHealth Group, Inc.
# Processing:UNM Unum Group
# Processing:UNM Unum Group
# Processing:UNP Union Pacific Corp.
# Processing:UNP Union Pacific Corp.
# Processing:UPS United Parcel Service, Inc.
# Processing:UPS United Parcel Service, Inc.
# Processing:URI United Rentals, Inc.
# Processing:URI United Rentals, Inc.
# Processing:USB U.S. Bancorp
# Processing:USB U.S. Bancorp
# Processing:UTX United Technologies Corp.
# Processing:UTX United Technologies Corp.
# Processing:V Visa, Inc.
# Processing:V Visa, Inc.
# Processing:VAR Varian Medical Systems, Inc.
# Processing:VAR Varian Medical Systems, Inc.
# Processing:VFC VF Corp.
# Processing:VFC VF Corp.
# Processing:VIAB Viacom Inc.
# Processing:VIAB Viacom Inc.
# Processing:VLO Valero Energy Corp.
# Processing:VLO Valero Energy Corp.
# Processing:VMC Vulcan Materials Co.
# Processing:VMC Vulcan Materials Co.
# Processing:VNO Vornado Realty Trust
# Processing:VNO Vornado Realty Trust
# Processing:VRSK Verisk Analytics, Inc.
# Processing:VRSK Verisk Analytics, Inc.
# Processing:VRSN VeriSign, Inc.
# Processing:VRSN VeriSign, Inc.
# Processing:VRTX Vertex Pharmaceuticals, Inc.
# Processing:VRTX Vertex Pharmaceuticals, Inc.
# Processing:VTR Ventas, Inc.
# Processing:VTR Ventas, Inc.
# Processing:VZ Verizon Communications, Inc.
# Processing:VZ Verizon Communications, Inc.
# Processing:WAB Westinghouse Air Brake Technologies Corp.
# Processing:WAB Westinghouse Air Brake Technologies Corp.
# Processing:WAT Waters Corp.
# Processing:WAT Waters Corp.
# Processing:WBA Walgreens Boots Alliance, Inc.
# Processing:WBA Walgreens Boots Alliance, Inc.
# Processing:WCG WellCare Health Plans, Inc.
# Processing:WCG WellCare Health Plans, Inc.
# Processing:WDC Western Digital Corp.
# Processing:WDC Western Digital Corp.
# Processing:WEC WEC Energy Group, Inc.
# Processing:WEC WEC Energy Group, Inc.
# Processing:WELL Welltower, Inc.
# Processing:WELL Welltower, Inc.
# Processing:WFC Wells Fargo & Co.
# Processing:WFC Wells Fargo & Co.
# Processing:WHR Whirlpool Corp.
# Processing:WHR Whirlpool Corp.
# Processing:WLTW Willis Towers Watson Plc
# Processing:WLTW Willis Towers Watson Plc
# Processing:WM Waste Management, Inc.
# Processing:WM Waste Management, Inc.
# Processing:WMB The Williams Cos., Inc.
# Processing:WMB The Williams Cos., Inc.
# Processing:WMT Walmart, Inc.
# Processing:WMT Walmart, Inc.
# Processing:WRK WestRock Co.
# Processing:WRK WestRock Co.
# Processing:WU The Western Union Co.
# Processing:WU The Western Union Co.
# Processing:WY Weyerhaeuser Co.
# Processing:WY Weyerhaeuser Co.
# Processing:WYNN Wynn Resorts Ltd.
# Processing:WYNN Wynn Resorts Ltd.
# Processing:XEC Cimarex Energy Co.
# Processing:XEC Cimarex Energy Co.
# Processing:XEL Xcel Energy, Inc.
# Processing:XEL Xcel Energy, Inc.
# Processing:XLNX Xilinx, Inc.
# Processing:XLNX Xilinx, Inc.
# Processing:XOM Exxon Mobil Corp.
# Processing:XOM Exxon Mobil Corp.
# Processing:XRAY Dentsply Sirona, Inc.
# Processing:XRAY Dentsply Sirona, Inc.
# Processing:XRX Xerox Holdings Corp.
# Processing:XRX Xerox Holdings Corp.
# Processing:XYL Xylem, Inc.
# Processing:XYL Xylem, Inc.
# Processing:YUM Yum! Brands, Inc.
# Processing:YUM Yum! Brands, Inc.
# Processing:ZBH Zimmer Biomet Holdings, Inc.
# Processing:ZBH Zimmer Biomet Holdings, Inc.
# Processing:ZION Zions Bancorporation NA
# Processing:ZION Zions Bancorporation NA
# Processing:ZTS Zoetis, Inc.
# Processing:ZTS Zoetis, Inc.
# Processing:Data Provided by IEX Cloud Certain securities may be excluded due to data limitations
# Processing:Data Provided by IEX Cloud Certain securities may be excluded due to data limitations
# Processing:Data updated on 2020-02-12 nan
# Processing:Data updated on 2020-02-12 nan
#                                                   priceBookValueRatio  \
# symbol name
# A      Agilent Technologies, Inc.                             4.52285
# AAL    American Airlines Group, Inc.                          0.00000
# AAP    Advance Auto Parts, Inc.                               2.76620
# AAPL   Apple, Inc.                                           10.64980
# ABBV   AbbVie, Inc.                                          15.40735
# ABC    AmerisourceBergen Corp.                                6.44165
# ABMD   ABIOMED, Inc.                                         15.65515
# ABT    Abbott Laboratories                                    3.72530
# ACN    Accenture Plc                                          9.55305
# ADBE   Adobe, Inc.                                           11.76355
# ADI    Analog Devices, Inc.                                   3.07625
# ADM    Archer-Daniels-Midland Co.                             1.22415
# ADP    Automatic Data Processing, Inc.                       12.91370
# ADS    Alliance Data Systems Corp.                            5.54970
# ADSK   Autodesk, Inc.                                         0.00000
# AEE    Ameren Corp.                                           2.03045
# AEP    American Electric Power Co., Inc.                      1.94240
# AES    The AES Corp.                                          2.95005
# AFL    Aflac, Inc.                                            1.43900
# AGN    Allergan Plc                                           0.72635
# AIG    American International Group, Inc.                     0.72470
# AIV    Apartment Investment & Management Co.                  3.90255
# AIZ    Assurant, Inc.                                         1.18605
# AJG    Arthur J. Gallagher & Co.                              2.83115
# AKAM   Akamai Technologies, Inc.                              3.21095
# ALB    Albemarle Corp.                                        3.11755
# ALGN   Align Technology, Inc.                                14.46890
# ALK    Alaska Air Group, Inc.                                 2.32605
# ALL    The Allstate Corp.                                     1.47105
# ALLE   Allegion Plc                                          15.27520
# ...                                                               ...
# VTR    Ventas, Inc.                                           2.00085
# VZ     Verizon Communications, Inc.                           4.72645
# WAB    Westinghouse Air Brake Technologies Corp.              2.60095
# WAT    Waters Corp.                                           7.97850
# WBA    Walgreens Boots Alliance, Inc.                         2.24965
# WCG    WellCare Health Plans, Inc.                            3.25755
# WDC    Western Digital Corp.                                  1.71070
# WEC    WEC Energy Group, Inc.                                 2.21310
# WELL   Welltower, Inc.                                        1.72005
# WFC    Wells Fargo & Co.                                      1.27290
# WHR    Whirlpool Corp.                                        2.92800
# WLTW   Willis Towers Watson Plc                               1.95980
# WM     Waste Management, Inc.                                 6.12880
# WMB    The Williams Cos., Inc.                                2.06560
# WMT    Walmart, Inc.                                          3.93740
# WRK    WestRock Co.                                           0.99800
# WU     The Western Union Co.                                  0.00000
# WY     Weyerhaeuser Co.                                       2.40285
# WYNN   Wynn Resorts Ltd.                                     11.49210
# XEC    Cimarex Energy Co.                                     3.21270
# XEL    Xcel Energy, Inc.                                      2.10450
# XLNX   Xilinx, Inc.                                           9.42920
# XOM    Exxon Mobil Corp.                                      1.71245
# XRAY   Dentsply Sirona, Inc.                                  1.96925
# XRX    Xerox Holdings Corp.                                   1.18170
# XYL    Xylem, Inc.                                            4.60910
# YUM    Yum! Brands, Inc.                                      0.00000
# ZBH    Zimmer Biomet Holdings, Inc.                           2.00940
# ZION   Zions Bancorporation NA                                1.16405
# ZTS    Zoetis, Inc.                                          19.28545
#
#                                                   priceToBookRatio  \
# symbol name
# A      Agilent Technologies, Inc.                         15.21880
# AAL    American Airlines Group, Inc.                       0.00000
# AAP    Advance Auto Parts, Inc.                            5.00915
# AAPL   Apple, Inc.                                        10.64980
# ABBV   AbbVie, Inc.                                        0.00000
# ABC    AmerisourceBergen Corp.                             0.00000
# ABMD   ABIOMED, Inc.                                      16.38750
# ABT    Abbott Laboratories                                 0.00000
# ACN    Accenture Plc                                      18.47310
# ADBE   Adobe, Inc.                                        19.60895
# ADI    Analog Devices, Inc.                                0.00000
# ADM    Archer-Daniels-Midland Co.                          1.55605
# ADP    Automatic Data Processing, Inc.                    36.36975
# ADS    Alliance Data Systems Corp.                         3.49355
# ADSK   Autodesk, Inc.                                      0.00000
# AEE    Ameren Corp.                                        2.14980
# AEP    American Electric Power Co., Inc.                   1.94790
# AES    The AES Corp.                                       6.24970
# AFL    Aflac, Inc.                                         1.43900
# AGN    Allergan Plc                                        0.00000
# AIG    American International Group, Inc.                  0.72470
# AIV    Apartment Investment & Management Co.               3.90255
# AIZ    Assurant, Inc.                                      2.18445
# AJG    Arthur J. Gallagher & Co.                           0.00000
# AKAM   Akamai Technologies, Inc.                           6.58050
# ALB    Albemarle Corp.                                     6.92800
# ALGN   Align Technology, Inc.                             15.58775
# ALK    Alaska Air Group, Inc.                              5.54645
# ALL    The Allstate Corp.                                  1.64685
# ALLE   Allegion Plc                                        0.00000
# ...                                                            ...
# VTR    Ventas, Inc.                                        2.22095
# VZ     Verizon Communications, Inc.                        0.00000
# WAB    Westinghouse Air Brake Technologies Corp.           0.00000
# WAT    Waters Corp.                                       12.03195
# WBA    Walgreens Boots Alliance, Inc.                      0.00000
# WCG    WellCare Health Plans, Inc.                         9.05610
# WDC    Western Digital Corp.                               0.00000
# WEC    WEC Energy Group, Inc.                              3.24160
# WELL   Welltower, Inc.                                     1.72815
# WFC    Wells Fargo & Co.                                   1.46505
# WHR    Whirlpool Corp.                                     0.00000
# WLTW   Willis Towers Watson Plc                            0.00000
# WM     Waste Management, Inc.                              0.00000
# WMB    The Williams Cos., Inc.                            16.44205
# WMT    Walmart, Inc.                                       6.00100
# WRK    WestRock Co.                                       16.90820
# WU     The Western Union Co.                               0.00000
# WY     Weyerhaeuser Co.                                    2.40285
# WYNN   Wynn Resorts Ltd.                                  13.14575
# XEC    Cimarex Energy Co.                                  4.15635
# XEL    Xcel Energy, Inc.                                   2.10450
# XLNX   Xilinx, Inc.                                       10.70050
# XOM    Exxon Mobil Corp.                                   1.71245
# XRAY   Dentsply Sirona, Inc.                               0.00000
# XRX    Xerox Holdings Corp.                                6.09815
# XYL    Xylem, Inc.                                         0.00000
# YUM    Yum! Brands, Inc.                                   0.00000
# ZBH    Zimmer Biomet Holdings, Inc.                        0.00000
# ZION   Zions Bancorporation NA                             1.34270
# ZTS    Zoetis, Inc.                                        0.00000
#
#                                                   priceToSalesRatio  \
# symbol name
# A      Agilent Technologies, Inc.                           4.54935
# AAL    American Airlines Group, Inc.                        0.46345
# AAP    Advance Auto Parts, Inc.                             1.01720
# AAPL   Apple, Inc.                                          4.01155
# ABBV   AbbVie, Inc.                                         4.90090
# ABC    AmerisourceBergen Corp.                              0.10750
# ABMD   ABIOMED, Inc.                                       18.54495
# ABT    Abbott Laboratories                                  3.94525
# ACN    Accenture Plc                                        2.91475
# ADBE   Adobe, Inc.                                         12.84105
# ADI    Analog Devices, Inc.                                 5.87555
# ADM    Archer-Daniels-Midland Co.                           0.36280
# ADP    Automatic Data Processing, Inc.                      4.78315
# ADS    Alliance Data Systems Corp.                          1.43835
# ADSK   Autodesk, Inc.                                      12.46410
# AEE    Ameren Corp.                                         2.41385
# AEP    American Electric Power Co., Inc.                    2.29235
# AES    The AES Corp.                                        0.78715
# AFL    Aflac, Inc.                                          1.59515
# AGN    Allergan Plc                                         3.20450
# AIG    American International Group, Inc.                   0.90790
# AIV    Apartment Investment & Management Co.                6.69575
# AIZ    Assurant, Inc.                                       0.76060
# AJG    Arthur J. Gallagher & Co.                            1.87535
# AKAM   Akamai Technologies, Inc.                            4.06005
# ALB    Albemarle Corp.                                      3.57815
# ALGN   Align Technology, Inc.                              10.37065
# ALK    Alaska Air Group, Inc.                               1.03855
# ALL    The Allstate Corp.                                   0.82140
# ALLE   Allegion Plc                                         2.96370
# ...                                                             ...
# VTR    Ventas, Inc.                                         5.76540
# VZ     Verizon Communications, Inc.                         1.75390
# WAB    Westinghouse Air Brake Technologies Corp.            1.80315
# WAT    Waters Corp.                                         6.32260
# WBA    Walgreens Boots Alliance, Inc.                       0.42505
# WCG    WellCare Health Plans, Inc.                          0.55420
# ...
# ALL    The Allstate Corp.                                             0.05625
# ALLE   Allegion Plc                                                   1.60080
# ...                                                                       ...
# VTR    Ventas, Inc.                                                  -0.02730
# VZ     Verizon Communications, Inc.                                   0.56565
# WAB    Westinghouse Air Brake Technologies Corp.                      0.10985
# WAT    Waters Corp.                                                  -0.14520
# WBA    Walgreens Boots Alliance, Inc.                                -0.00100
# WCG    WellCare Health Plans, Inc.                                    0.43530
# WDC    Western Digital Corp.                                         -0.07075
# WEC    WEC Energy Group, Inc.                                         0.04725
# WELL   Welltower, Inc.                                               -0.02625
# WFC    Wells Fargo & Co.                                              0.01790
# WHR    Whirlpool Corp.                                               -0.24580
# WLTW   Willis Towers Watson Plc                                       0.01530
# WM     Waste Management, Inc.                                         0.10925
# WMB    The Williams Cos., Inc.                                        0.58895
# WMT    Walmart, Inc.                                                 -0.00580
# WRK    WestRock Co.                                                   0.05640
# WU     The Western Union Co.                                         -0.61200
# WY     Weyerhaeuser Co.                                              -0.03025
# WYNN   Wynn Resorts Ltd.                                              3.01015
# XEC    Cimarex Energy Co.                                             0.27255
# XEL    Xcel Energy, Inc.                                              0.05110
# XLNX   Xilinx, Inc.                                                   0.07430
# XOM    Exxon Mobil Corp.                                              0.06025
# XRAY   Dentsply Sirona, Inc.                                         -0.21675
# XRX    Xerox Holdings Corp.                                           0.06425
# XYL    Xylem, Inc.                                                    0.12220
# YUM    Yum! Brands, Inc.                                             -0.28935
# ZBH    Zimmer Biomet Holdings, Inc.                                   0.07765
# ZION   Zions Bancorporation NA                                        0.02240
# ZTS    Zoetis, Inc.                                                   0.22810
#
#                                                   Debt Growth  \
# symbol name
# A      Agilent Technologies, Inc.                    -0.02460
# AAL    American Airlines Group, Inc.                  0.19360
# AAP    Advance Auto Parts, Inc.                       0.00130
# AAPL   Apple, Inc.                                   -0.03325
# ABBV   AbbVie, Inc.                                   0.04650
# ABC    AmerisourceBergen Corp.                        0.09635
# ABMD   ABIOMED, Inc.                                 -0.50000
# ABT    Abbott Laboratories                           -0.01520
# ACN    Accenture Plc                                 -0.04825
# ADBE   Adobe, Inc.                                    0.59335
# ADI    Analog Devices, Inc.                           1.66955
# ADM    Archer-Daniels-Midland Co.                     0.10025
# ADP    Automatic Data Processing, Inc.                0.06535
# ADS    Alliance Data Systems Corp.                    0.04210
# ADSK   Autodesk, Inc.                                 0.19010
# AEE    Ameren Corp.                                   0.07400
# AEP    American Electric Power Co., Inc.              0.07275
# AES    The AES Corp.                                 -0.00365
# AFL    Aflac, Inc.                                    0.03965
# AGN    Allergan Plc                                  -0.14545
# AIG    American International Group, Inc.             0.05765
# AIV    Apartment Investment & Management Co.          0.02470
# AIZ    Assurant, Inc.                                 0.43950
# AJG    Arthur J. Gallagher & Co.                      0.12620
# AKAM   Akamai Technologies, Inc.                      0.69495
# ALB    Albemarle Corp.                               -0.14820
# ALGN   Align Technology, Inc.                         0.00000
# ALK    Alaska Air Group, Inc.                        -0.15735
# ALL    The Allstate Corp.                             0.00820
# ALLE   Allegion Plc                                  -0.00640
# ...                                                       ...
# VTR    Ventas, Inc.                                  -0.01735
# VZ     Verizon Communications, Inc.                   0.02450
# WAB    Westinghouse Air Brake Technologies Corp.      0.52505
# WAT    Waters Corp.                                  -0.16595
# WBA    Walgreens Boots Alliance, Inc.                 0.14120
# WCG    WellCare Health Plans, Inc.                    0.49180
# WDC    Western Digital Corp.                         -0.10435
# WEC    WEC Energy Group, Inc.                         0.07685
# WELL   Welltower, Inc.                                0.04135
# WFC    Wells Fargo & Co.                             -0.02350
# WHR    Whirlpool Corp.                                0.16115
# WLTW   Willis Towers Watson Plc                       0.09110
# WM     Waste Management, Inc.                         0.03790
# WMB    The Williams Cos., Inc.                       -0.01930
# WMT    Walmart, Inc.                                  0.13020
# WRK    WestRock Co.                                   0.27370
# WU     The Western Union Co.                          0.11035
# WY     Weyerhaeuser Co.                              -0.03240
# WYNN   Wynn Resorts Ltd.                             -0.03520
# XEC    Cimarex Energy Co.                            -0.00700
# XEL    Xcel Energy, Inc.                              0.07770
# XLNX   Xilinx, Inc.                                  -0.04945
# XOM    Exxon Mobil Corp.                             -0.05860
# XRAY   Dentsply Sirona, Inc.                          0.04050
# XRX    Xerox Holdings Corp.                          -0.08925
# XYL    Xylem, Inc.                                   -0.01090
# YUM    Yum! Brands, Inc.                              0.05085
# ZBH    Zimmer Biomet Holdings, Inc.                  -0.10825
# ZION   Zions Bancorporation NA                        1.56235
# ZTS    Zoetis, Inc.                                   0.20555
#
#                                                   R&D Expense Growth  \
# symbol name
# A      Agilent Technologies, Inc.                            0.08305
# AAL    American Airlines Group, Inc.                         0.00000
# AAP    Advance Auto Parts, Inc.                              0.00000
# AAPL   Apple, Inc.                                           0.18425
# ABBV   AbbVie, Inc.                                          0.60235
# ABC    AmerisourceBergen Corp.                               0.00000
# ABMD   ABIOMED, Inc.                                         0.18800
# ABT    Abbott Laboratories                                   0.28980
# ACN    Accenture Plc                                         0.00000
# ADBE   Adobe, Inc.                                           0.25525
# ADI    Analog Devices, Inc.                                  0.34235
# ADM    Archer-Daniels-Midland Co.                            0.00000
# ADP    Automatic Data Processing, Inc.                       0.00000
# ADS    Alliance Data Systems Corp.                           0.00000
# ADSK   Autodesk, Inc.                                       -0.02710
# AEE    Ameren Corp.                                          0.00000
# AEP    American Electric Power Co., Inc.                     0.00000
# AES    The AES Corp.                                         0.00000
# AFL    Aflac, Inc.                                           0.00000
# AGN    Allergan Plc                                         -0.05275
# AIG    American International Group, Inc.                    0.00000
# AIV    Apartment Investment & Management Co.                 0.00000
# AIZ    Assurant, Inc.                                        0.00000
# AJG    Arthur J. Gallagher & Co.                             0.00000
# AKAM   Akamai Technologies, Inc.                             0.21685
# ALB    Albemarle Corp.                                      -0.06070
# ALGN   Align Technology, Inc.                                0.30480
# ALK    Alaska Air Group, Inc.                                0.00000
# ALL    The Allstate Corp.                                    0.00000
# ALLE   Allegion Plc                                          0.00000
# ...                                                              ...
# VTR    Ventas, Inc.                                          0.00000
# VZ     Verizon Communications, Inc.                          0.00000
# WAB    Westinghouse Air Brake Technologies Corp.             0.12610
# WAT    Waters Corp.                                          0.07035
# WBA    Walgreens Boots Alliance, Inc.                        0.00000
# WCG    WellCare Health Plans, Inc.                           0.00000
# WDC    Western Digital Corp.                                -0.05380
# WEC    WEC Energy Group, Inc.                                0.00000
# WELL   Welltower, Inc.                                       0.00000
# WFC    Wells Fargo & Co.                                     0.00000
# WHR    Whirlpool Corp.                                       0.00000
# WLTW   Willis Towers Watson Plc                              0.00000
# WM     Waste Management, Inc.                                0.00000
# WMB    The Williams Cos., Inc.                               0.00000
# WMT    Walmart, Inc.                                         0.00000
# WRK    WestRock Co.                                          0.00000
# WU     The Western Union Co.                                 0.00000
# WY     Weyerhaeuser Co.                                     -0.34590
# WYNN   Wynn Resorts Ltd.                                     0.00000
# XEC    Cimarex Energy Co.                                    0.00000
# XEL    Xcel Energy, Inc.                                     0.00000
# XLNX   Xilinx, Inc.                                          0.11255
# XOM    Exxon Mobil Corp.                                     0.01960
# XRAY   Dentsply Sirona, Inc.                                 0.00000
# XRX    Xerox Holdings Corp.                                 -0.07395
# XYL    Xylem, Inc.                                           0.34485
# YUM    Yum! Brands, Inc.                                     0.00000
# ZBH    Zimmer Biomet Holdings, Inc.                          0.03535
# ZION   Zions Bancorporation NA                               0.00000
# ZTS    Zoetis, Inc.                                          0.07345
#
#                                                   SG&A Expenses Growth
# symbol name
# A      Agilent Technologies, Inc.                              0.04940
# AAL    American Airlines Group, Inc.                           0.05905
# AAP    Advance Auto Parts, Inc.                                0.02095
# AAPL   Apple, Inc.                                             0.09340
# ABBV   AbbVie, Inc.                                            0.12290
# ABC    AmerisourceBergen Corp.                                 0.11920
# ABMD   ABIOMED, Inc.                                           0.21415
# ABT    Abbott Laboratories                                     0.21215
# ACN    Accenture Plc                                           0.09220
# ADBE   Adobe, Inc.                                             0.16380
# ADI    Analog Devices, Inc.                                    0.25235
# ADM    Archer-Daniels-Midland Co.                              0.04650
# ADP    Automatic Data Processing, Inc.                         0.05115
# ADS    Alliance Data Systems Corp.                             0.09990
# ADSK   Autodesk, Inc.                                          0.07855
# AEE    Ameren Corp.                                            0.00000
# AEP    American Electric Power Co., Inc.                       0.00000
# AES    The AES Corp.                                           0.00060
# AFL    Aflac, Inc.                                             0.02385
# AGN    Allergan Plc                                           -0.02020
# AIG    American International Group, Inc.                     -0.01995
# AIV    Apartment Investment & Management Co.                  -0.00350
# AIZ    Assurant, Inc.                                         -0.05655
# AJG    Arthur J. Gallagher & Co.                               0.09215
# AKAM   Akamai Technologies, Inc.                               0.12165
# ALB    Albemarle Corp.                                         0.13175
# ALGN   Align Technology, Inc.                                  0.31860
# ALK    Alaska Air Group, Inc.                                  0.24725
# ALL    The Allstate Corp.                                      0.07150
# ALLE   Allegion Plc                                            0.08030
# ...                                                                ...
# VTR    Ventas, Inc.                                            0.09480
# VZ     Verizon Communications, Inc.                            0.05225
# WAB    Westinghouse Air Brake Technologies Corp.               0.30380
# WAT    Waters Corp.                                            0.02440
# WBA    Walgreens Boots Alliance, Inc.                          0.02960
# WCG    WellCare Health Plans, Inc.                             0.22800
# WDC    Western Digital Corp.                                  -0.04325
# WEC    WEC Energy Group, Inc.                                  0.00000
# WELL   Welltower, Inc.                                        -0.08910
# WFC    Wells Fargo & Co.                                       0.01975
# WHR    Whirlpool Corp.                                         0.02595
# WLTW   Willis Towers Watson Plc                                0.02785
# WM     Waste Management, Inc.                                  0.01545
# WMB    The Williams Cos., Inc.                                -0.10970
# WMT    Walmart, Inc.                                           0.02585
# WRK    WestRock Co.                                            0.12020
# WU     The Western Union Co.                                  -0.15730
# WY     Weyerhaeuser Co.                                       -0.02380
# WYNN   Wynn Resorts Ltd.                                       0.18070
# XEC    Cimarex Energy Co.                                      0.04660
# XEL    Xcel Energy, Inc.                                       0.00000
# XLNX   Xilinx, Inc.                                            0.09035
# XOM    Exxon Mobil Corp.                                       0.04885
# XRAY   Dentsply Sirona, Inc.                                   0.06305
# XRX    Xerox Holdings Corp.                                   -0.04775
# XYL    Xylem, Inc.                                             0.12880
# YUM    Yum! Brands, Inc.                                      -0.10960
# ZBH    Zimmer Biomet Holdings, Inc.                            0.07140
# ZION   Zions Bancorporation NA                                 0.04115
# ZTS    Zoetis, Inc.                                            0.04520
#
# [501 rows x 92 columns]

# %%
# dropping columns with little to no data.
dataframe2 = dataframe2.drop(columns=['priceCashFlowRatio', 'priceEarningsToGrowthRatio', 'priceSalesRatio', 'dividendYield', 'priceFairValue', 'operatingProfitMargin'])

# %%
# replacing all the 0 values with -99 in the dataframes for the purpose of machine learning to indicate nan.
sandp  = dataframe2.replace(0,-99)

# %%
# changing all the column names for the purpose of sql.
sandp = sandp.rename(columns = {'priceBookValueRatio': 'price_to_bookvalue', 'priceToBookRatio': 'price_to_book',
           'priceToSalesRatio': 'price_to_sales', 'priceEarningsRatio': 'price_to_earnings', 'receivablesTurnover': 'receivables_turnover',
           'priceToFreeCashFlowsRatio': 'price_to_free_cash_flow', 'priceToOperatingCashFlowsRatio': 'price_to_operating_cash_flow',
           'enterpriseValueMultiple': 'enterprise_value_multiple', 'niperEBT': 'niper_ebt', 'ebtperEBIT': 'ebt_per_ebit', 'ebitperRevenue': 'ebit_per_revenue',
           'grossProfitMargin': 'gross_profit_margin', 'pretaxProfitMargin': 'pretax_profit_margin', 'netProfitMargin': 'net_profit_margin',
           'effectiveTaxRate': 'tax_rate', 'returnOnAssets': 'return_on_assets', 'returnOnEquity': 'return_on_equity',
           'returnOnCapitalEmployed': 'return_on_capital_employed', 'nIperEBT': 'niper_ebt', 'eBTperEBIT': 'ebt_per_ebit', 'eBITperRevenue': 'ebit_per_revenue',
           'receivablesTurnover.1': 'receivables_turnover_1', 'payablesTurnover': 'payables_turnover', 'inventoryTurnover': 'inventory_turnover',
           'fixedAssetTurnover': 'fixed_asset_turnover', 'assetTurnover': 'asset_turnover', 'currentRatio': 'current_ratio', 'quickRatio': 'quick_ratio',
           'cashRatio': 'cash_ratio', 'daysOfSalesOutstanding': 'days_of_sales_outstanding', 'daysOfInventoryOutstanding': 'days_of_inventory_outstanding',
           'operatingCycle': 'operating_cycle', 'daysOfPayablesOutstanding': 'days_of_payables_outstanding', 'cashConversionCycle': 'cash_conversion_cycle',
           'debtRatio': 'debt_ratio', 'debtEquityRatio':'debt_to_equity_ratio', 'longtermDebtToCapitalization': 'longterm_debt_to_capitalization',
           'totalDebtToCapitalization': 'total_debt_to_capitalization', 'interestCoverage': 'interest_coverage', 'cashFlowToDebtRatio': 'cash_flow_to_debt',
           'companyEquityMultiplier': 'company_equity_multiplier', 'operatingCashFlowPerShare': 'operating_cash_flow_per_share',
           'freeCashFlowPerShare': 'free_cash_flow_per_share', 'cashPerShare': 'cash_per_share', 'payoutRatio': 'payout_ratio',
           'receivablesTurnover.2': 'receivables_turnover_2', 'operatingCashFlowSalesRatio': 'operating_cash_flow_to_sales',
           'freeCashFlowOperatingCashFlowRatio': 'free_cash_flow_to_operating_cash_flow', 'cashFlowCoverageRatios': 'cash_flow_coverage_ratio',
           'shortTermCoverageRatios': 'short_term_coverage_ratio', 'capitalExpenditureCoverageRatios': 'capital_expenditure_coverage_ratio',
           'dividendpaidAndCapexCoverageRatios': 'dividend_capex_coverage_ratio', 'dividendPayoutRatio': 'dividend_payout_ratio',
           'Gross Profit Growth': 'gross_profit_growth', 'EBIT Growth': 'ebit_growth', 'Operating Income Growth': 'operating_income_growth',
           'Net Income Growth': 'net_income_growth', 'EPS Growth': 'eps_growth', 'EPS Diluted Growth': 'eps_diluted_growth',
           'Weighted Average Shares Growth': 'weighted_average_share_growth',
           'Weighted Average Shares Diluted Growth': 'weighted_averages_shares_diluted_growth', 'Dividends per Share Growth': 'dividents_per_share_growth',
           'Operating Cash Flow growth': 'operating_cash_flow_growth', 'Free Cash Flow growth': 'free_cash_flow_growth',
           '10Y Revenue Growth (per Share)': 'ten_year_revenue_growth_per_share', '5Y Revenue Growth (per Share)': 'five_year_revenue_growth_per_share',
           '3Y Revenue Growth (per Share)': 'three_year_revenue_growth_per_share', '10Y Operating CF Growth (per Share)': 'ten_year_operating_cf_growth_per_share',
           '5Y Operating CF Growth (per Share)': 'five_year_operating_cf_growth_per_share',
           '3Y Operating CF Growth (per Share)': 'three_year_operating_cf_growth_per_share',
           '10Y Net Income Growth (per Share)': 'ten_year_net_income_growth_per_share', '5Y Net Income Growth (per Share)': 'five_year_net_income_growth_per_share',
           '3Y Net Income Growth (per Share)': 'three_year_net_income_growth_per_share',
           '10Y Shareholders Equity Growth (per Share)':'ten_year_shareholders_equity_growth_per_share',
           '5Y Shareholders Equity Growth (per Share)':'five_year_shareholders_equity_growth_per_share',
           '3Y Shareholders Equity Growth (per Share)':'three_year_shareholders_equity_growth_per_share',
           '10Y Dividend per Share Growth (per Share)':'ten_year_dividend_growth_per_share',
           '5Y Dividend per Share Growth (per Share)':'five_year_dividend_growth_per_share',
           '3Y Dividend per Share Growth (per Share)':'three_year_dividend_growth_per_share', 'Receivables growth': 'receivables_growh',
           'Inventory Growth': 'inventory_growth', 'Asset Growth': 'asset_growth', 'Book Value per Share Growth': 'book_value_per_share_growth',
           'Debt Growth': 'debt_growth', 'R&D Expense Growth':'randd_expense_growth', 'SG&A Expenses Growth': 'sganda_expense_growth',
           '% return on investment': 'percent_return_on_investment'})

# %%
# dropping all unecessary columns.
sandp = sandp.drop(columns=['niper_ebt', 'ebt_per_ebit',  'ebit_per_revenue'])

# %%
# reseting the index of the sandp dataframe.
sandp = sandp.reset_index()
sandp
# Out:
#     symbol                                       name  price_to_bookvalue  \
# 0        A                 Agilent Technologies, Inc.             4.52285
# 1      AAL              American Airlines Group, Inc.           -99.00000
# 2      AAP                   Advance Auto Parts, Inc.             2.76620
# 3     AAPL                                Apple, Inc.            10.64980
# 4     ABBV                               AbbVie, Inc.            15.40735
# 5      ABC                    AmerisourceBergen Corp.             6.44165
# 6     ABMD                              ABIOMED, Inc.            15.65515
# 7      ABT                        Abbott Laboratories             3.72530
# 8      ACN                              Accenture Plc             9.55305
# 9     ADBE                                Adobe, Inc.            11.76355
# 10     ADI                       Analog Devices, Inc.             3.07625
# 11     ADM                 Archer-Daniels-Midland Co.             1.22415
# 12     ADP            Automatic Data Processing, Inc.            12.91370
# 13     ADS                Alliance Data Systems Corp.             5.54970
# 14    ADSK                             Autodesk, Inc.           -99.00000
# 15     AEE                               Ameren Corp.             2.03045
# 16     AEP          American Electric Power Co., Inc.             1.94240
# 17     AES                              The AES Corp.             2.95005
# 18     AFL                                Aflac, Inc.             1.43900
# 19     AGN                               Allergan Plc             0.72635
# 20     AIG         American International Group, Inc.             0.72470
# 21     AIV      Apartment Investment & Management Co.             3.90255
# 22     AIZ                             Assurant, Inc.             1.18605
# 23     AJG                  Arthur J. Gallagher & Co.             2.83115
# 24    AKAM                  Akamai Technologies, Inc.             3.21095
# 25     ALB                            Albemarle Corp.             3.11755
# 26    ALGN                     Align Technology, Inc.            14.46890
# 27     ALK                     Alaska Air Group, Inc.             2.32605
# 28     ALL                         The Allstate Corp.             1.47105
# 29    ALLE                               Allegion Plc            15.27520
# ..     ...                                        ...                 ...
# 471    VTR                               Ventas, Inc.             2.00085
# 472     VZ               Verizon Communications, Inc.             4.72645
# 473    WAB  Westinghouse Air Brake Technologies Corp.             2.60095
# 474    WAT                               Waters Corp.             7.97850
# 475    WBA             Walgreens Boots Alliance, Inc.             2.24965
# 476    WCG                WellCare Health Plans, Inc.             3.25755
# 477    WDC                      Western Digital Corp.             1.71070
# 478    WEC                     WEC Energy Group, Inc.             2.21310
# 479   WELL                            Welltower, Inc.             1.72005
# 480    WFC                          Wells Fargo & Co.             1.27290
# 481    WHR                            Whirlpool Corp.             2.92800
# 482   WLTW                   Willis Towers Watson Plc             1.95980
# 483     WM                     Waste Management, Inc.             6.12880
# 484    WMB                    The Williams Cos., Inc.             2.06560
# 485    WMT                              Walmart, Inc.             3.93740
# 486    WRK                               WestRock Co.             0.99800
# 487     WU                      The Western Union Co.           -99.00000
# 488     WY                           Weyerhaeuser Co.             2.40285
# 489   WYNN                          Wynn Resorts Ltd.            11.49210
# 490    XEC                         Cimarex Energy Co.             3.21270
# 491    XEL                          Xcel Energy, Inc.             2.10450
# 492   XLNX                               Xilinx, Inc.             9.42920
# 493    XOM                          Exxon Mobil Corp.             1.71245
# 494   XRAY                      Dentsply Sirona, Inc.             1.96925
# 495    XRX                       Xerox Holdings Corp.             1.18170
# 496    XYL                                Xylem, Inc.             4.60910
# 497    YUM                          Yum! Brands, Inc.           -99.00000
# 498    ZBH               Zimmer Biomet Holdings, Inc.             2.00940
# 499   ZION                    Zions Bancorporation NA             1.16405
# 500    ZTS                               Zoetis, Inc.            19.28545
#
#      price_to_book  price_to_sales  price_to_earnings  receivables_turnover  \
# 0         15.21880         4.54935           49.10090               6.57635
# 1        -99.00000         0.46345           15.39385              25.61875
# 2          5.00915         1.01720           21.92895              15.29405
# 3         10.64980         4.01155           18.81675               5.88140
# 4        -99.00000         4.90090           27.42550               5.99340
# 5        -99.00000         0.10750           16.21085              15.34590
# 6         16.38750        18.54495           79.01220               9.57025
# 7        -99.00000         3.94525          135.85915               6.15495
# 8         18.47310         2.91475           26.15330               5.61395
# 9         19.60895        12.84105           49.92760               7.12415
# 10       -99.00000         5.87555           32.59070               9.04530
# 11         1.55605         0.36280           13.54055              31.18390
# 12        36.36975         4.78315           31.54120               6.73150
# 13         3.49355         1.43835           13.28290               7.21825
# 14       -99.00000        12.46410          -99.00000               5.12570
# 15         2.14980         2.41385           23.28115               7.53655
# 16         1.94790         2.29235           18.88925               8.29350
# 17         6.24970         0.78715            3.97255               7.16200
# 18         1.43900         1.59515            9.79585              27.44995
# 19       -99.00000         3.20450          -99.00000               5.67315
# 20         0.72470         0.90790          -99.00000               4.61990
# 21         3.90255         6.69575           15.80380             -99.00000
# 22         2.18445         0.76060           16.43025               0.66975
# 23       -99.00000         1.87535           22.26190               1.82980
# 24         6.58050         4.06005           42.37270               5.88225
# 25         6.92800         3.57815          140.23540               5.53580
# 26        15.58775        10.37065           59.80460               5.15435
# 27         5.54645         1.03855           13.38490              23.96570
# 28         1.64685         0.82140           12.83130               5.29240
# 29       -99.00000         2.96370           22.62355               8.72200
# ..             ...             ...                ...                   ...
# 471        2.22095         5.76540           33.29590             -99.00000
# 472      -99.00000         1.75390           11.10765               5.76650
# 473      -99.00000         1.80315           26.61195               3.72635
# 474       12.03195         6.32260          403.61410               4.45245
# 475      -99.00000         0.42505           12.59815              19.95880
# 476        9.05610         0.55420           24.61455              18.02045
# 477      -99.00000         0.98135           17.05065               9.85300
# 478        3.24160         2.77970           18.93780               5.86855
# 479        1.72815         5.52030           42.50480               4.38255
# 480        1.46505         3.03280           12.72370             -99.00000
# 481      -99.00000         0.44610           17.57220               8.26860
# 482      -99.00000         2.34210           31.81075               3.73665
# 483      -99.00000         2.56250           19.60575               6.42260
# 484       16.44205         3.13935            5.92015               8.60950
# 485        6.00100         0.58615           37.21595              86.94010
# 486       16.90820         0.67630            9.01660               8.52885
# 487      -99.00000         1.46885            4.51325               1.39445
# 488        2.40285         2.94675           33.96250              19.35440
# 489       13.14575         2.19155           20.43220              27.11400
# 490        4.15635         4.37635           15.79645               4.83155
# 491        2.10450         2.16155           20.55115               7.35085
# 492       10.70050         8.93370           36.98670               8.20390
# 493        1.71245         1.23460           16.16920              10.97005
# 494      -99.00000         3.12215          -99.00000               5.64195
# 495        6.09815         0.60370           27.74025               2.04320
# 496      -99.00000         2.45005           29.43500               5.23700
# 497      -99.00000         4.86255           20.14495              13.55260
# 498      -99.00000         2.94295            6.90755               5.29160
# 499        1.34270         3.34655           14.02625             -99.00000
# 500      -99.00000         6.82265           34.83850               5.64090
#
#      price_to_free_cash_flow  price_to_operating_cash_flow  \
# 0                   26.77630                      21.81385
# 1                    7.43180                       4.76540
# 2                   18.65350                      13.60055
# 3                   17.56185                      14.38080
# 4                   13.88110                      13.05080
# 5                   13.65700                      10.77060
# 6                   75.03970                      56.91995
# 7                   24.49190                      19.26800
# 8                   20.18525                      19.39800
# 9                   32.55695                      30.38725
# 10                  23.95680                      21.11530
# 11                 -99.00000                      -4.27965
# 12                  31.52225                      25.27900
# 13                   4.60805                       4.19755
# 14                  51.95435                   14191.21695
# 15                 -99.00000                       7.01630
# 16                  24.10470                       7.69825
# 17                  32.55565                       3.47840
# 18                   5.75755                       5.70550
# 19                   9.11320                       8.65565
# 20                 290.21445                     282.34960
# 21                  14.54095                      16.79190
# 22                  10.13230                       9.25945
# 23                  18.31470                      15.42475
# 24                  23.04110                      11.85535
# 25                 -99.00000                      31.39880
# 26                  62.33835                      35.63335
# 27                  24.14765                       6.04165
# 28                   7.52835                       6.98860
# 29                  21.88100                      19.21265
# ..                       ...                           ...
# 471                 19.27290                      15.00775
# 472                 22.02150                       7.87245
# 473                 53.82185                      31.86710
# 474                 27.03910                      22.97485
# 475                 10.89635                       8.18810
# 476                 48.87675                      25.44580
# 477                 12.17270                       7.25730
# 478                120.26955                       9.46070
# 479                  9.85200                      16.49800
# 480                 11.21015                      11.08495
# 481                 16.23470                       7.54970
# 482                 30.13995                      18.91785
# 483                 21.29880                      11.19210
# 484                 36.30675                       8.22010
# 485                 16.38115                      10.58790
# 486                 11.42325                       5.57045
# 487                 13.07000                      10.50420
# 488                 25.53420                      18.45705
# 489                  9.04025                      10.09250
# 490                  6.38415                       7.35170
# 491                -99.00000                       7.93760
# 492                 27.54795                      25.77555
# 493                 21.06505                       9.99970
# 494                 29.34250                      22.31205
# 495                  2.24215                     -11.93715
# 496                 29.01000                      19.14155
# 497                 34.54800                      25.55415
# 498                 19.56310                      13.99115
# 499                 10.47215                       8.78525
# 500                 29.89815                      24.47115
#
#      enterprise_value_multiple  ...  ten_year_dividend_growth_per_share  \
# 0                    21.977547  ...                           -99.00000
# 1                     8.055577  ...                           -99.00000
# 2                    13.648477  ...                           -99.00000
# 3                     8.253489  ...                           -99.00000
# 4                    20.321289  ...                           -99.00000
# 5                    10.530870  ...                             0.24290
# 6                    58.762337  ...                           -99.00000
# 7                    21.504509  ...                            -0.02015
# 8                     8.728855  ...                             0.19785
# 9                    38.230155  ...                           -99.00000
# 10                   18.923121  ...                             0.09630
# 11                    9.936130  ...                             0.11055
# 12                   11.899417  ...                             0.08875
# 13                   12.092158  ...                           -99.00000
# 14                  250.682194  ...                           -99.00000
# 15                    9.298116  ...                            -0.03315
# 16                   10.132343  ...                             0.04330
# 17                    9.554258  ...                           -99.00000
# 18                   10.326138  ...                             0.08060
# 19                   43.130521  ...                           -99.00000
# 20                   11.792950  ...                            -0.20960
# 21                   10.208414  ...                            -0.12555
# 22                   13.189115  ...                             0.16080
# 23                   18.927617  ...                             0.02415
# 24                   16.054069  ...                           -99.00000
# 25                   15.268788  ...                             0.11300
# 26                   40.061131  ...                           -99.00000
# 27                    7.748279  ...                           -99.00000
# 28                    9.316559  ...                             0.00445
# 29                   15.850876  ...                           -99.00000
# ..                         ...  ...                                 ...
# 471                  14.841731  ...                             0.04750
# 472                   7.889473  ...                             0.02820
# 473                  20.139425  ...                             0.36815
# 474                  21.103366  ...                           -99.00000
# 475                   5.575543  ...                             0.14670
# 476                  20.105825  ...                           -99.00000
# 477                   7.404555  ...                           -99.00000
# 478                  11.357944  ...                             0.15225
# 479                  16.703949  ...                             0.03445
# 480                  19.131881  ...                             0.02525
# 481                  12.995957  ...                             0.09910
# 482                  15.250793  ...                            -0.01785
# 483                  11.379168  ...                             0.05735
# 484                  14.958595  ...                             0.12050
# 485                  13.444104  ...                             0.08460
# 486                   5.355494  ...                           -99.00000
# 487                  12.177403  ...                             0.33690
# 488                  16.315182  ...                            -0.06060
# 489                  21.442830  ...                            -0.05200
# 490                   8.122534  ...                             0.09410
# 491                  10.353804  ...                             0.04780
# 492                  29.389426  ...                             0.10600
# 493                   7.752754  ...                             0.07995
# 494                 -99.000000  ...                             0.07195
# 495                  10.054022  ...                             0.10450
# 496                  17.020164  ...                           -99.00000
# 497                  14.278631  ...                             0.08205
# 498                  23.414008  ...                           -99.00000
# 499                   8.835474  ...                            -0.08410
# 500                  21.778659  ...                           -99.00000
#
#      five_year_dividend_growth_per_share  \
# 0                                0.08645
# 1                              -99.00000
# 2                              -99.00000
# 3                                0.10710
# 4                                0.08770
# 5                                0.09450
# 6                              -99.00000
# 7                               -0.30915
# 8                                0.09935
# 9                              -99.00000
# 10                               0.08225
# 11                               0.12665
# 12                               0.09240
# 13                             -99.00000
# 14                             -99.00000
# 15                               0.02525
# 16                               0.05135
# 17                               0.45480
# 18                               0.06645
# 19                               0.47915
# 20                               0.22480
# 21                               0.11625
# 22                               0.17535
# 23                               0.03000
# 24                             -99.00000
# 25                               0.08380
# 26                             -99.00000
# 27                               0.22480
# 28                               0.11965
# 29                             -99.00000
# ..                                   ...
# 471                              0.03805
# 472                              0.02790
# 473                              0.35245
# 474                            -99.00000
# 475                              0.07145
# 476                            -99.00000
# 477                              0.12365
# 478                              0.10250
# 479                              0.02950
# 480                              0.09600
# 481                              0.15215
# 482                             -0.04985
# 483                              0.04310
# 484                             -0.15570
# 485                              0.03575
# 486                            -99.00000
# 487                              0.09610
# 488                              0.12655
# 489                             -0.21905
# 490                             -0.00660
# 491                              0.06305
# 492                              0.08650
# 493                              0.06310
# 494                              0.08345
# 495                              0.02685
# 496                              0.12355
# 497                              0.00550
# 498                              0.04815
# 499                              0.56555
# 500                              0.10455
#
#      three_year_dividend_growth_per_share  receivables_growh  \
# 0                                -0.33325            0.10960
# 1                                 0.12995            0.03640
# 2                               -99.00000           -0.01185
# 3                                 0.11195            0.15415
# 4                                 0.18330            0.06380
# 5                                 0.07500            0.09645
# 6                               -99.00000            0.29615
# 7                                 0.05835            0.30165
# 8                                 0.09575            0.08110
# 9                               -99.00000            0.27110
# 10                                0.06625            0.18550
# 11                                0.08110            0.08445
# 12                               -0.13225            0.19310
# 13                              -99.00000            0.94805
# 14                              -99.00000            0.02560
# 15                                0.03555            0.02645
# 16                                0.05580            0.00270
# 17                                0.21515            0.05990
# 18                                0.07335            0.13260
# 19                                1.73765            0.06735
# 20                                0.26640            0.02690
# 21                                0.05870          -99.00000
# 22                                0.22545            0.02535
# 23                                0.03090            0.70140
# 24                              -99.00000            0.14590
# 25                                0.05055            0.11660
# 26                              -99.00000            0.33225
# 27                                0.20625            0.10120
# 28                                0.12525           -0.26650
# 29                                0.27025            0.11810
# ..                                    ...                ...
# 471                              -0.16705          -99.00000
# 472                              -0.01120            0.20500
# 473                               0.24870            0.11045
# 474                             -99.00000            0.07775
# 475                               0.06495            0.05310
# 476                             -99.00000            0.64685
# 477                               0.01785           -0.16210
# 478                               0.07315            0.01805
# 479                               0.02420           -0.03895
# 480                               0.04045          -99.00000
# 481                               0.12010           -0.09385
# 482                              -0.11280            0.06950
# 483                               0.05380            0.03590
# 484                              -0.16440            0.02845
# 485                               0.02020            0.04065
# 486                               0.36405            0.07825
# 487                               0.09445            0.01390
# 488                               0.05120           -0.06680
# 489                              -0.15185            0.12895
# 490                              -0.08410            0.31070
# 491                               0.06085            0.03555
# 492                               0.05790            0.22195
# 493                               0.04080            0.08075
# 494                               0.08155            0.05695
# 495                              -0.05180            0.00760
# 496                               0.13120            0.10625
# 497                              -0.06390            0.24180
# 498                               0.02940           -0.10570
# 499                               0.53965          -99.00000
# 500                               0.14165            0.06560
#
#      inventory_growth  asset_growth  book_value_per_share_growth  debt_growth  \
# 0             0.09420       0.04735                      0.05050     -0.02460
# 1             0.18105       0.08860                     -0.22415      0.19360
# 2             0.00510       0.04295                      0.10400      0.00130
# 3            -0.07365      -0.05000                     -0.12605     -0.03325
# 4             0.05575      -0.04530                     -1.29920      0.04650
# 5            -0.01605       0.05325                      0.22070      0.09635
# 6             0.52475       0.38475                      0.41475     -0.50000
# 7             0.26685       0.16440                      0.12600     -0.01520
# 8           -99.00000       0.14795                      0.25595     -0.04825
# 9           -99.00000       0.21800                      0.13190      0.59335
# 10            0.26405       0.80965                      0.39510      1.66955
# 11           -0.00025       0.01335                      0.07400      0.10025
# 12          -99.00000       0.06155                      0.18260      0.06535
# 13           -0.03885       0.09650                      0.22620      0.04210
# 14          -99.00000       0.00345                     -0.58995      0.19010
# 15           -0.04210       0.04965                      0.03420      0.07400
# 16           -0.02415       0.04140                      0.04450      0.07275
# 17           -0.03490      -0.05060                      0.08910     -0.00365
# 18          -99.00000       0.04010                      0.11470      0.03965
# 19            0.09800      -0.11120                     -0.00455     -0.14545
# 20          -99.00000      -0.00630                     -0.05135      0.05765
# 21          -99.00000      -0.00320                     -0.02500      0.02470
# 22          -99.00000       0.18110                      0.13605      0.43950
# 23          -99.00000       0.19660                      0.10240      0.12620
# 24          -99.00000       0.11895                      0.01830      0.69495
# 25            0.24915      -0.03605                     -0.01045     -0.14820
# 26            0.46195       0.21415                      0.12105    -99.00000
# 27            0.13270       0.04705                      0.13385     -0.15735
# 28          -99.00000       0.01680                      0.05625      0.00820
# 29            0.12795       0.11830                      1.60080     -0.00640
# ..                ...           ...                          ...          ...
# 471         -99.00000      -0.01160                     -0.02730     -0.01735
# 472           0.07615       0.04150                      0.56565      0.02450
# 473           0.13270       0.15715                      0.10985      0.52505
# 474           0.05385      -0.07890                     -0.14520     -0.16595
# 475           0.02525       0.01215                     -0.00100      0.14120
# 476         -99.00000       0.38300                      0.43530      0.49180
# 477           0.18635      -0.05945                     -0.07075     -0.10435
# 478          -0.03280       0.05420                      0.04725      0.07685
# 479         -99.00000       0.02695                     -0.02625      0.04135
# 480         -99.00000      -0.00870                      0.01790     -0.02350
# 481          -0.00655      -0.01910                     -0.24580      0.16115
# 482         -99.00000       0.03535                      0.01530      0.09110
# 483           0.06460       0.04205                      0.10925      0.03790
# 484          -0.01540      -0.01650                      0.58895     -0.01930
# 485           0.01410       0.05045                     -0.00580      0.13020
# 486           0.08495       0.09995                      0.05640      0.27370
# 487         -99.00000      -0.02270                     -0.61200      0.11035
# 488           0.04275      -0.05320                     -0.03025     -0.03240
# 489          -0.14365       0.05150                      3.01015     -0.03520
# 490           0.30430       0.19605                      0.27255     -0.00700
# 491          -0.04585       0.05715                      0.05110      0.07770
# 492           0.18780       0.04270                      0.07430     -0.04945
# 493           0.12125       0.02420                      0.06025     -0.05860
# 494           0.08310      -0.13245                     -0.21675      0.04050
# 495          -0.00900      -0.09190                      0.06425     -0.08925
# 496           0.06965       0.05620                      0.12220     -0.01090
# 497          -0.50000      -0.12420                     -0.28935      0.05085
# 498           0.07330      -0.04880                      0.07765     -0.10825
# 499         -99.00000       0.04265                      0.02240      1.56235
# 500          -0.03755       0.18885                      0.22810      0.20555
#
#      randd_expense_growth  sganda_expense_growth
# 0                 0.08305                0.04940
# 1               -99.00000                0.05905
# 2               -99.00000                0.02095
# 3                 0.18425                0.09340
# 4                 0.60235                0.12290
# 5               -99.00000                0.11920
# 6                 0.18800                0.21415
# 7                 0.28980                0.21215
# 8               -99.00000                0.09220
# 9                 0.25525                0.16380
# 10                0.34235                0.25235
# 11              -99.00000                0.04650
# 12              -99.00000                0.05115
# 13              -99.00000                0.09990
# 14               -0.02710                0.07855
# 15              -99.00000              -99.00000
# 16              -99.00000              -99.00000
# 17              -99.00000                0.00060
# 18              -99.00000                0.02385
# 19               -0.05275               -0.02020
# 20              -99.00000               -0.01995
# 21              -99.00000               -0.00350
# 22              -99.00000               -0.05655
# 23              -99.00000                0.09215
# 24                0.21685                0.12165
# 25               -0.06070                0.13175
# 26                0.30480                0.31860
# 27              -99.00000                0.24725
# 28              -99.00000                0.07150
# 29              -99.00000                0.08030
# ..                    ...                    ...
# 471             -99.00000                0.09480
# 472             -99.00000                0.05225
# 473               0.12610                0.30380
# 474               0.07035                0.02440
# 475             -99.00000                0.02960
# 476             -99.00000                0.22800
# 477              -0.05380               -0.04325
# 478             -99.00000              -99.00000
# 479             -99.00000               -0.08910
# 480             -99.00000                0.01975
# 481             -99.00000                0.02595
# 482             -99.00000                0.02785
# 483             -99.00000                0.01545
# 484             -99.00000               -0.10970
# 485             -99.00000                0.02585
# 486             -99.00000                0.12020
# 487             -99.00000               -0.15730
# 488              -0.34590               -0.02380
# 489             -99.00000                0.18070
# 490             -99.00000                0.04660
# 491             -99.00000              -99.00000
# 492               0.11255                0.09035
# 493               0.01960                0.04885
# 494             -99.00000                0.06305
# 495              -0.07395               -0.04775
# 496               0.34485                0.12880
# 497             -99.00000               -0.10960
# 498               0.03535                0.07140
# 499             -99.00000                0.04115
# 500               0.07345                0.04520
#
# [501 rows x 82 columns]

# %%
# creating an empty list.
ticker_symbols = []
# looping through the ticker symbol column of dataframe and appending to the empty list.
for symbol in sandp['symbol']:
    ticker_symbols.append(symbol)

# %%
# creating empty list.
industry_list = []

# creating empty list.
sector_list = []

# looping through ticker_symbols list.
for ticker in ticker_symbols:
    
    # try except statement to ignore missing data.    
    try:

        # obtaining the json data for sector and industry type from financialmodelingprep.          
        response = requests.get(f'https://financialmodelingprep.com/api/v3/company/profile/{ticker}').json()

        # getting industry data.
        industry_list.append(response['profile']['industry'])
        
        # getting sector data.
        sector_list.append(response['profile']['sector'])
    
    # try except statement to ignore missing data.
    except:
        pass

# %%
# adding industry to dataframe.
sandp['industry'] = industry_list

# %%
# adding sector to dataframe.
sandp['sector'] = sector_list

# %%
# verifying the above_below_sandp column was added.
sandp.head()
# Out:
#   symbol                           name  price_to_bookvalue  price_to_book  \
# 0      A     Agilent Technologies, Inc.             4.52285       15.21880
# 1    AAL  American Airlines Group, Inc.           -99.00000      -99.00000
# 2    AAP       Advance Auto Parts, Inc.             2.76620        5.00915
# 3   AAPL                    Apple, Inc.            10.64980       10.64980
# 4   ABBV                   AbbVie, Inc.            15.40735      -99.00000
#
#    price_to_sales  price_to_earnings  receivables_turnover  \
# 0         4.54935           49.10090               6.57635
# 1         0.46345           15.39385              25.61875
# 2         1.01720           21.92895              15.29405
# 3         4.01155           18.81675               5.88140
# 4         4.90090           27.42550               5.99340
#
#    price_to_free_cash_flow  price_to_operating_cash_flow  \
# 0                 26.77630                      21.81385
# 1                  7.43180                       4.76540
# 2                 18.65350                      13.60055
# 3                 17.56185                      14.38080
# 4                 13.88110                      13.05080
#
#    enterprise_value_multiple  ...  three_year_dividend_growth_per_share  \
# 0                  21.977547  ...                              -0.33325
# 1                   8.055577  ...                               0.12995
# 2                  13.648477  ...                             -99.00000
# 3                   8.253489  ...                               0.11195
# 4                  20.321289  ...                               0.18330
#
#    receivables_growh  inventory_growth  asset_growth  \
# 0            0.10960           0.09420       0.04735
# 1            0.03640           0.18105       0.08860
# 2           -0.01185           0.00510       0.04295
# 3            0.15415          -0.07365      -0.05000
# 4            0.06380           0.05575      -0.04530
#
#    book_value_per_share_growth  debt_growth  randd_expense_growth  \
# 0                      0.05050     -0.02460               0.08305
# 1                     -0.22415      0.19360             -99.00000
# 2                      0.10400      0.00130             -99.00000
# 3                     -0.12605     -0.03325               0.18425
# 4                     -1.29920      0.04650               0.60235
#
#    sganda_expense_growth                        industry             sector
# 0                0.04940  Medical Diagnostics & Research         Healthcare
# 1                0.05905                        Airlines        Industrials
# 2                0.02095    Retail - Apparel & Specialty  Consumer Cyclical
# 3                0.09340               Computer Hardware         Technology
# 4                0.12290              Drug Manufacturers         Healthcare
#
# [5 rows x 84 columns]

# %%
# creating a connection to an aws rds postgres cloud database.
rds_connection_string = f'postgres:{postgress_password}@localhost:5432/{database_name}'
engine = create_engine(f'postgres://{rds_connection_string}')

# %%
# checking out the table names in the cloud database.
engine.table_names()
# Out:
# []

# %%
# appedending pandas dataframe to cloud postgres database.
sandp.to_sql(name='sandp19', con=engine, if_exists="replace", index=False)

# %%
# checking to to see if above process worked.
pd.read_sql_query('SELECT * FROM sandp19', con=engine).head()
# Out:
#   symbol                           name  price_to_bookvalue  price_to_book  \
# 0      A     Agilent Technologies, Inc.             4.52285       15.21880
# 1    AAL  American Airlines Group, Inc.           -99.00000      -99.00000
# 2    AAP       Advance Auto Parts, Inc.             2.76620        5.00915
# 3   AAPL                    Apple, Inc.            10.64980       10.64980
# 4   ABBV                   AbbVie, Inc.            15.40735      -99.00000
#
#    price_to_sales  price_to_earnings  receivables_turnover  \
# 0         4.54935           49.10090               6.57635
# 1         0.46345           15.39385              25.61875
# 2         1.01720           21.92895              15.29405
# 3         4.01155           18.81675               5.88140
# 4         4.90090           27.42550               5.99340
#
#    price_to_free_cash_flow  price_to_operating_cash_flow  \
# 0                 26.77630                      21.81385
# 1                  7.43180                       4.76540
# 2                 18.65350                      13.60055
# 3                 17.56185                      14.38080
# 4                 13.88110                      13.05080
#
#    enterprise_value_multiple  ...  three_year_dividend_growth_per_share  \
# 0                  21.977547  ...                              -0.33325
# 1                   8.055577  ...                               0.12995
# 2                  13.648477  ...                             -99.00000
# 3                   8.253489  ...                               0.11195
# 4                  20.321289  ...                               0.18330
#
#    receivables_growh  inventory_growth  asset_growth  \
# 0            0.10960           0.09420       0.04735
# 1            0.03640           0.18105       0.08860
# 2           -0.01185           0.00510       0.04295
# 3            0.15415          -0.07365      -0.05000
# 4            0.06380           0.05575      -0.04530
#
#    book_value_per_share_growth  debt_growth  randd_expense_growth  \
# 0                      0.05050     -0.02460               0.08305
# 1                     -0.22415      0.19360             -99.00000
# 2                      0.10400      0.00130             -99.00000
# 3                     -0.12605     -0.03325               0.18425
# 4                     -1.29920      0.04650               0.60235
#
#    sganda_expense_growth                        industry             sector
# 0                0.04940  Medical Diagnostics & Research         Healthcare
# 1                0.05905                        Airlines        Industrials
# 2                0.02095    Retail - Apparel & Specialty  Consumer Cyclical
# 3                0.09340               Computer Hardware         Technology
# 4                0.12290              Drug Manufacturers         Healthcare
#
# [5 rows x 82 columns]
