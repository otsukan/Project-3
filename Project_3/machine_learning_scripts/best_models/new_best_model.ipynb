# %%
# importing necessary modules.
import pandas as pd
import config7 as cfg
from sqlalchemy import create_engine
import numpy as np
import matplotlib.pyplot as plt

# %%
# creating a connection to an aws rds postgres cloud database.
rds_connection_string = f'postgres:{cfg.password}@test-db.cy2enoewwvsi.us-east-2.rds.amazonaws.com:5432/stocks_db'
engine = create_engine(f'postgres://{rds_connection_string}')

# %%
# checking out the table names in the database.
engine.table_names()
# Out:
# ['sandp', 'avg_sandp', 'russell_2000', 'sandp_russell', 'new_route', 'sandp2']

# %%
# checking out the SandP_500 table.
sandp = pd.read_sql_query('SELECT * FROM sandp', con=engine)
sandp
# Out:
#     symbol                                       name  price_to_bookvalue  \
# 0        A                 Agilent Technologies, Inc.             2.55170
# 1      AAL              American Airlines Group, Inc.           -99.00000
# 2      AAP                   Advance Auto Parts, Inc.             2.95660
# 3     AAPL                                Apple, Inc.             5.42765
# 4     ABBV                               AbbVie, Inc.            16.46870
# 5      ABC                    AmerisourceBergen Corp.             2.65245
# 6     ABMD                              ABIOMED, Inc.             3.53820
# 7      ABT                        Abbott Laboratories             1.64610
# 8      ACN                              Accenture Plc             7.75270
# 9     ADBE                                Adobe, Inc.             3.28150
# 10     ADI                       Analog Devices, Inc.             3.06315
# 11     ADM                 Archer-Daniels-Midland Co.             1.19775
# 12     ADP            Automatic Data Processing, Inc.             3.06475
# 13     ADS                Alliance Data Systems Corp.            86.00770
# 14    ADSK                             Autodesk, Inc.             3.70520
# 15     AEE                               Ameren Corp.             0.85900
# 16     AEP          American Electric Power Co., Inc.             1.26715
# 17     AES                              The AES Corp.             1.69175
# 18     AFL                                Aflac, Inc.             2.48160
# 19     AGN                               Allergan Plc             1.68725
# 20     AIG         American International Group, Inc.             0.07605
# 21     AIV      Apartment Investment & Management Co.             2.11910
# 22     AIZ                             Assurant, Inc.             0.78465
# 23     AJG                  Arthur J. Gallagher & Co.             2.67590
# 24    AKAM                  Akamai Technologies, Inc.             3.22645
# 25     ALB                            Albemarle Corp.             3.18510
# 26    ALGN                     Align Technology, Inc.             4.40700
# 27     ALK                     Alaska Air Group, Inc.             1.62350
# 28     ALL                         The Allstate Corp.             0.93795
# 29    ALXN              Alexion Pharmaceuticals, Inc.             7.33710
# ..     ...                                        ...                 ...
# 438   VRTX               Vertex Pharmaceuticals, Inc.            10.62580
# 439    VTR                               Ventas, Inc.             3.55135
# 440     VZ               Verizon Communications, Inc.             2.37930
# 441    WAB  Westinghouse Air Brake Technologies Corp.             2.64615
# 442    WAT                               Waters Corp.             6.85440
# 443    WBA             Walgreens Boots Alliance, Inc.             2.07640
# 444    WCG                WellCare Health Plans, Inc.             1.65235
# 445    WDC                      Western Digital Corp.             1.65740
# 446    WEC                     WEC Energy Group, Inc.             1.72140
# 447   WELL                            Welltower, Inc.             1.43200
# 448    WFC                          Wells Fargo & Co.             1.21985
# 449    WHR                            Whirlpool Corp.             1.63175
# 465                 13.32785                      10.07295
# 466                  2.27505                       2.30265
# 467                 47.27130                      34.15200
#
#      enterprise_value_multiple  ...  asset_growth  \
# 0                    16.746223  ...       0.18005
# 1                    61.812855  ...      -0.00170
# 2                     0.499984  ...       0.03670
# 3                     0.493341  ...       0.44800
# 4                     0.001609  ...     -99.00000
# 5                     2.439843  ...       0.08720
# 6                   -99.000000  ...      -0.04700
# 7                     2.092158  ...       0.19580
# 8                     1.573638  ...       0.01790
# 9                     1.887970  ...       0.18440
# 10                    1.864944  ...       0.18740
# 11                    2.156508  ...      -0.07025
# 12                    0.898339  ...       0.06385
# 13                    4.666244  ...       0.39325
# 14                    4.274720  ...       0.01090
# 15                    4.283875  ...       0.01870
# 16                    3.559501  ...       0.05715
# 17                    5.555798  ...       0.08030
# 18                    0.789317  ...       0.13075
# 19                    2.205036  ...       0.28420
# 20                    0.183378  ...      -0.10430
# 21                    0.460224  ...      -0.11470
# 22                    1.470457  ...       0.03780
# 23                    4.042344  ...       0.05000
# 24                    0.534661  ...       0.11840
# 25                    3.147074  ...       0.03590
# 26                    1.268037  ...       0.30715
# 27                    2.712487  ...       0.01865
# 28                    0.377560  ...      -0.01465
# 29                    1.689852  ...       0.46680
# ..                         ...  ...           ...
# 438                 -99.000000  ...       0.43840
# 439                   0.163274  ...      -0.00085
# 440                   2.162876  ...       0.04545
# 441                   2.711751  ...       0.09445
# 442                   1.904852  ...       0.19780
# 443                   0.999405  ...       0.08350
# 444                   4.848049  ...       0.01110
# 445                   1.831895  ...       0.23515
# 446                   3.468231  ...       0.01740
# 447                   0.290782  ...       0.25445
# 448                   4.005875  ...      -0.01940
# 449                   3.254338  ...       0.07395
# 450                   2.736055  ...      -0.01650
# 451                   2.962336  ...       0.03050
# 452                   5.998510  ...      -0.02005
# 453                   1.441004  ...       0.04270
# 454                   1.307154  ...       0.19825
# 455                  21.456055  ...      -0.10300
# 456                   7.100485  ...       0.00130
# 457                   0.184975  ...       0.04615
# 458                   3.524453  ...       0.04810
# 459                   2.808993  ...       0.13240
# 460                   0.344382  ...       0.15980
# 461                   2.213671  ...       0.07305
# 462                   6.678674  ...       0.17195
# 463                   0.257340  ...       0.23670
# 464                   1.005792  ...       0.11285
# 465                   1.388154  ...       0.05150
# 466                 -99.000000  ...      -0.03690
# 467                   2.033149  ...     -99.00000
#
#      book_value_per_share_growth  debt_growth  randd_expense_growth  \
# 0                        0.15185      0.31885              -0.06740
# 1                       -0.06235      0.00975             -99.00000
# 2                        0.19520     -0.57150             -99.00000
# 3                        0.44245    -99.00000               0.26940
# 4                      -99.00000    -99.00000               0.46130
# 5                        0.11490      0.06560             -99.00000
# 6                       -0.11940    -99.00000               0.02470
# 7                        0.15215      0.29370               0.18890
# 8                        0.03930     -0.11090             -99.00000
# 9                        0.10660      1.18980               0.02870
# 10                       0.14065      0.02765              -0.03035
# 11                       0.04265     -0.16605             -99.00000
# 12                       0.05440      5.07190             -99.00000
# 13                      -0.63550      1.14890             -99.00000
# 14                       0.10860     -1.00000              -0.20590
# 15                      -0.00820     -0.02270             -99.00000
# 16                       0.03455      0.00575             -99.00000
# 17                       0.21845      0.03305             -99.00000
# 18                       0.29655      0.33955             -99.00000
# 19                       0.16740      0.17880               0.33035
# 20                       0.24995     -0.27255             -99.00000
# 21                      -0.20570     -0.07585             -99.00000
# 22                       0.17950      0.00010             -99.00000
# 23                       0.15925      0.01690             -99.00000
# 24                       0.14745     -0.50025               0.18345
# 25                       0.15450     -0.03445              -0.06805
# 26                       0.23440    -99.00000               0.00935
# 27                       0.30215     -0.08270             -99.00000
# 28                       0.23970      0.02205             -99.00000
# 29                       0.86535     -0.72365               0.25505
# ..                           ...          ...                   ...
# 438                      1.06095      1.01290               0.11145
# 439                     -0.00650     -0.03135             -99.00000
# 440                     -0.03465      0.02315             -99.00000
# 441                      0.18910      0.04470               0.01800
# 442                      0.31775      0.19545               0.01900
# 443                      0.06275      0.33845             -99.00000
# 444                      0.01040     -0.50000             -99.00000
# 445                      0.31555     -0.11155               0.14870
# 446                      0.06740      0.03385             -99.00000
# 447                      0.02500      0.34965             -99.00000
# 448                     -0.08905     -0.23915             -99.00000
# 449                      0.17810     -0.00895             -99.00000
# 450                      0.10255     -0.07465             -99.00000
# 451                      0.04595      0.03475             -99.00000
# 452                     -0.09915      0.08760             -99.00000
# 453                      0.09980     -0.02130             -99.00000
# 454                     23.86365      0.02450             -99.00000
# 455                     -0.20350     -0.08250              -0.28030
# 456                      0.21680     -0.12655             -99.00000
# 457                      0.05405     -0.21185             -99.00000
# 458                      0.04895      0.07655             -99.00000
# 459                      0.08860      0.00760               0.03970
# 460                      0.14955      0.29110               0.22685
# 461                      0.09695      0.17385             -99.00000
# 462                      0.09625      0.01705              -0.06000
# 463                      0.30585    -99.00000               0.07950
# 464                      5.47095      0.00430             -99.00000
# 465                      0.07770      0.73185               0.06595
# 466                     -0.17925     -0.18970             -99.00000
# 467                    -99.00000    -99.00000               0.11680
#
#      sganda_expense_growth  percent_return_on_investment  \
# 0                  0.01880                    215.407785
# 1                  0.01435                    492.976589
# 2                  0.10360                    158.290852
# 3                  0.21645                    641.441749
# 4                  0.14080                    127.493713
# 5                  0.01405                    258.118955
# 6                  0.09900                   2583.734150
# 7                  0.11545                    167.453799
# 8                  0.02345                    363.726903
# 9                  0.08435                    750.511115
# 10                -0.01315                    246.609146
# 11                -0.00740                     64.206780
# 12                -0.05015                    316.688209
# 13                 0.03240                    239.244869
# 14                -0.15980                    263.535571
# 15               -99.00000                    139.465663
# 16               -99.00000                    132.233503
# 17                 0.03730                      9.185370
# 18                 0.09395                     80.824950
# 19                 0.34105                    275.621207
# 20                -0.17670                     40.946389
# 21                -0.17650                    138.045466
# 22                 0.04925                    195.412982
# 23                 0.05895                    231.883775
# 24                 0.14780                     63.019014
# 25                 0.06245                    157.434695
# 26                 0.00470                   1296.549758
# 27                 0.01115                    546.990741
# 28                -0.09160                    228.134086
# 29                 0.30315                    289.700834
# ..                     ...                           ...
# 438                0.36390                    343.862520
# 439                0.11925                     19.653341
# 440               -0.11950                     74.553287
# 441                0.08020                    292.734448
# 442                0.02235                    189.448146
# 443                0.08420                    100.116240
# 444               -0.00315                    641.367414
# 445                0.11600                    115.194407
# 446              -99.00000                    167.967572
# 447                0.07610                     55.301524
# 448                0.52050                     98.919308
# 449               -0.05120                     94.347855
# 450                0.06875                    104.254647
# 451               -0.00270                    158.140221
# 452                0.09105                     55.032422
# 453                0.03130                     76.422465
# 454                0.04880                      5.230011
# 455               -0.18090                      7.577338
# 456                0.10750                     62.888525
# 457                0.05145                     53.257576
# 458              -99.00000                    135.121731
# 459               -0.04710                    219.745638
# 460               -0.03760                     11.745946
# 461                0.00295                     58.835219
# 462                0.01120                     10.848508
# 463                0.01500                    182.394085
# 464               -0.02215                    185.642194
# 465                0.01605                     16.093672
# 466                0.00150                    198.122919
# 467                0.29640                    119.637182
#
#      above_below_sandp_return    market_cap                         industry  \
# 0                           1  7.462700e+09   Medical Diagnostics & Research
# 1                           1  6.133809e+08                         Airlines
# 2                           1  1.912092e+09     Retail - Apparel & Specialty
# 3                           1  9.151793e+10                Computer Hardware
# 4                           0  6.619065e+10               Drug Manufacturers
# 5                           1  7.017275e+09             Medical Distribution
# 6                           1  4.310088e+08                  Medical Devices
# 7                           1  3.765926e+10               Drug Manufacturers
# 8                           1  2.405644e+10             Application Software
# 9                           1  8.597522e+09             Application Software
# 10                          1  3.873230e+09                   Semiconductors
# 11                          0  1.716488e+10          Consumer Packaged Goods
# 12                          1  1.747092e+10                Business Services
# 13                          1  3.344989e+09                  Credit Services
# 14                          1  7.404290e+09             Application Software
# 15                          0  6.633966e+09            Utilities - Regulated
# 16                          0  7.890918e+09            Utilities - Regulated
# 17                          0  8.584759e+09            Utilities - Regulated
# 18                          0  1.707002e+10                 Insurance - Life
# 19                          1  5.111720e+09               Drug Manufacturers
# 20                          0  4.963071e+09                        Insurance
# 21                          0  7.862957e+08                            REITs
# 22                          1  3.784939e+09                        Insurance
# 23                          1  1.146777e+09              Brokers & Exchanges
# 24                          0  6.781676e+09             Application Software
# 25                          1  4.098402e+09                        Chemicals
# 26                          1  1.317932e+09                  Medical Devices
# 27                          1  7.934756e+08                         Airlines
# 28                          1  1.574118e+10  Insurance - Property & Casualty
# 29                          1  3.742952e+09                    Biotechnology
# ..                        ...           ...                              ...
# 438                         1  6.963840e+09                    Biotechnology
# 439                         0  3.872078e+09                            REITs
# 440                         0  8.885368e+10           Communication Services
# 441                         1  1.490843e+09       Transportation & Logistics
# 442                         1  6.446795e+09                Computer Hardware
# 443                         0  2.956389e+10               Drug Manufacturers
# 444                         1  7.359261e+08                Health Care Plans
# 445                         0  2.597400e+09                Computer Hardware
# 446                         1  4.438945e+09            Utilities - Regulated
# 447                         0  5.674635e+09                            REITs
# 448                         0  6.556746e+10                            Banks
# 449                         0  5.689419e+09                Computer Hardware
# 450                         0  2.291224e+09              Brokers & Exchanges
# 451                         1  8.128223e+09                 Waste Management
# 452                         0  1.035534e+10            Oil & Gas - Midstream
# 453                         0  2.045623e+11               Retail - Defensive
# 454                         0  6.398545e+09                            Banks
# 455                         0  7.006733e+09                  Forest Products
# 456                         0  1.051933e+10                 Travel & Leisure
# 457                         0  2.015144e+09                  Oil & Gas - E&P
# 458                         0  1.019276e+10            Utilities - Regulated
# 459                         1  3.626840e+09                   Semiconductors
# 460                         0  3.547153e+11           Oil & Gas - Integrated
# 461                         0  4.785689e+09  Medical Instruments & Equipment
# 462                         0  7.615220e+09             Application Software
# 463                         1  2.393827e+09              Industrial Products
# 464                         1  8.527000e+03                      Restaurants
# 465                         0  1.842290e+10                  Medical Devices
# 466                         1  2.559168e+09                            Banks
# 467                         0  1.890344e+10               Drug Manufacturers
#
#                      sector
# 0                Healthcare
# 1               Industrials
# 2         Consumer Cyclical
# 3                Technology
# 4                Healthcare
# 5                Healthcare
# 6                Healthcare
# 7                Healthcare
# 8                Technology
# 9                Technology
# 10               Technology
# 11       Consumer Defensive
# 12              Industrials
# 13       Financial Services
# 14               Technology
# 15                Utilities
# 16                Utilities
# 17                Utilities
# 18       Financial Services
# 19               Healthcare
# 20       Financial Services
# 21              Real Estate
# 22       Financial Services
# 23       Financial Services
# 24               Technology
# 25          Basic Materials
# 26               Healthcare
# 27              Industrials
# 28       Financial Services
# 29               Healthcare
# ..                      ...
# 438              Healthcare
# 439             Real Estate
# 440  Communication Services
# 441             Industrials
# 442              Technology
# 443              Healthcare
# 444              Healthcare
# 445              Technology
# 446               Utilities
# 447             Real Estate
# 448      Financial Services
# 449              Technology
# 450      Financial Services
# 451             Industrials
# 452                  Energy
# 453      Consumer Defensive
# 454      Financial Services
# 455         Basic Materials
# 456       Consumer Cyclical
# 457                  Energy
# 458               Utilities
# 459              Technology
# 460                  Energy
# 461              Healthcare
# 462              Technology
# 463             Industrials
# 464       Consumer Cyclical
# 465              Healthcare
# 466      Financial Services
# 467              Healthcare
#
# [468 rows x 87 columns]

# %%
# converting industry columns into 1's and 0's.
industry = pd.get_dummies(sandp['industry'])

# %%
# converting sector columns into 1's and 0's.
sector = pd.get_dummies(sandp['sector'])

# %%
# bringing everything together.
sandp = pd.concat([sandp, industry, sector], axis=1)

# %%
# dropping industry and sector columns.
sandp.drop(['industry', 'sector'], axis=1, inplace=True)

# %%
sandp = sandp.drop(columns=['symbol', 'name'])

# %%
# dropping unnecessary columns.
sandp.drop(['percent_return_on_investment'], axis=1, inplace=True)

# %%
names = []
for x in sandp.columns:
    names.append(x)

# %%
X = sandp[['net_income_growth','short_term_coverage_ratio','eps_diluted_growth', 'gross_profit_margin', 'price_to_book', 'price_to_sales', 'price_to_free_cash_flow', 'asset_growth', 'Airlines',
'Computer Hardware','Drug Manufacturers', 'Medical Devices','Application Software', 'Semiconductors','Consumer Packaged Goods', 
'Business Services', 'Credit Services','Utilities - Regulated', 'Insurance - Life', 'REITs','Brokers & Exchanges','Biotechnology',
'Asset Management', 'Online Media','Oil & Gas - E&P','Autos', 'Banks', 'Travel & Leisure', 'Entertainment','Agriculture',
'Transportation & Logistics','Oil & Gas - Integrated','Industrial Distribution','Metals & Mining','Oil & Gas - Services',
'Personal Services','Engineering & Construction', 'Oil & Gas - Midstream','Beverages - Non-Alcoholic', 'Truck Manufacturing', 
'Employment Services', 'Forest Products']]
target = sandp['above_below_sandp_return']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, target_train, target_test = train_test_split(X, target, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
classifier.fit(X_train, target_train)
# Out:
# C:\Users\natha\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
print(f'Training Data Score: {classifier.score(X_train, target_train)}')
print(f'Testing Data Score: {classifier.score(X_test, target_test)}')
# Out:
# Training Data Score: 0.7207977207977208
# Testing Data Score: 0.7777777777777778

# %%
predictions = classifier.predict(X_test)
pd.DataFrame({'Prediction': predictions, 'Actual': target_test}).reset_index(drop=True).head()
# Out:
#    Prediction  Actual
# 0           0       0
# 1           0       1
# 2           1       1
# 3           1       1
# 4           1       1

# %%
target_test.value_counts()
# Out:
# 1    63
# 0    54
# Name: above_below_sandp_return, dtype: int64

# %%
target_test.mean()
# Out:
# 0.5384615384615384

# %%
from sklearn.metrics import classification_report
print(classification_report(target_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.67      0.73        54
#            1       0.75      0.87      0.81        63
#
#     accuracy                           0.78       117
#    macro avg       0.79      0.77      0.77       117
# weighted avg       0.78      0.78      0.77       117

# %%
predictions2 = classifier.predict(X)
pd.DataFrame({'Prediction': predictions2, 'Actual': target}).reset_index(drop=True).head()
# Out:
#    Prediction  Actual
# 0           1       1
# 1           1       1
# 2           1       1
# 3           0       1
# 4           0       0

# %%
# checking out the SandP_500 table.
sandp = pd.read_sql_query('SELECT * FROM sandp', con=engine)
sandp.head()
# Out:
#   symbol                           name  price_to_bookvalue  price_to_book  \
# 0      A     Agilent Technologies, Inc.             2.55170        5.17165
# 1    AAL  American Airlines Group, Inc.           -99.00000      -99.00000
# 2    AAP       Advance Auto Parts, Inc.             2.95660        3.10380
# 3   AAPL                    Apple, Inc.             5.42765        4.62715
# 4   ABBV                   AbbVie, Inc.            16.46870      -99.00000
#
#    price_to_sales  price_to_earnings  receivables_turnover  \
# 0         1.48130            6.30885                7.0014
# 1         0.11565          -99.00000               27.3348
# 2         0.70600           14.16840               57.0461
# 3         3.98235           19.54495               10.0906
# 4         3.01900           10.48360              -99.0000
#
#    price_to_free_cash_flow  price_to_operating_cash_flow  \
# 0                  18.1807                      13.57995
# 1                 -99.0000                       2.20925
# 2                   7.4185                       5.46130
# 3                  17.3279                      15.35960
# 4                   9.2123                       8.74540
#
#    enterprise_value_multiple  ...  asset_growth  book_value_per_share_growth  \
# 0                  16.746223  ...       0.18005                      0.15185
# 1                  61.812855  ...      -0.00170                     -0.06235
# 2                   0.499984  ...       0.03670                      0.19520
# 3                   0.493341  ...       0.44800                      0.44245
# 4                   0.001609  ...     -99.00000                    -99.00000
#
#    debt_growth  randd_expense_growth  sganda_expense_growth  \
# 0      0.31885               -0.0674                0.01880
# 1      0.00975              -99.0000                0.01435
# 2     -0.57150              -99.0000                0.10360
# 3    -99.00000                0.2694                0.21645
# 4    -99.00000                0.4613                0.14080
#
#    percent_return_on_investment  above_below_sandp_return    market_cap  \
# 0                    215.407785                         1  7.462700e+09
# 1                    492.976589                         1  6.133809e+08
# 2                    158.290852                         1  1.912092e+09
# 3                    641.441749                         1  9.151793e+10
# 4                    127.493713                         0  6.619065e+10
#
#                          industry             sector
# 0  Medical Diagnostics & Research         Healthcare
# 1                        Airlines        Industrials
# 2    Retail - Apparel & Specialty  Consumer Cyclical
# 3               Computer Hardware         Technology
# 4              Drug Manufacturers         Healthcare
#
# [5 rows x 87 columns]

# %%
sandp = sandp[['name', 'percent_return_on_investment', 'above_below_sandp_return']]

# %%
sandp.head()
# Out:
#                             name  percent_return_on_investment  \
# 0     Agilent Technologies, Inc.                    215.407785
# 1  American Airlines Group, Inc.                    492.976589
# 2       Advance Auto Parts, Inc.                    158.290852
# 3                    Apple, Inc.                    641.441749
# 4                   AbbVie, Inc.                    127.493713
#
#    above_below_sandp_return
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         0

# %%
sandp['predictions'] = predictions2

# %%
sandp.head()
# Out:
#                             name  percent_return_on_investment  \
# 0     Agilent Technologies, Inc.                    215.407785
# 1  American Airlines Group, Inc.                    492.976589
# 2       Advance Auto Parts, Inc.                    158.290852
# 3                    Apple, Inc.                    641.441749
# 4                   AbbVie, Inc.                    127.493713
#
#    above_below_sandp_return  predictions
# 0                         1            1
# 1                         1            1
# 2                         1            1
# 3                         1            0
# 4                         0            0

# %%
predicted_positives = []
for (x,y) in zip(sandp['predictions'],sandp['percent_return_on_investment']):
    if x == 1:
        predicted_positives.append(y)

# %%
predicted = pd.DataFrame(predicted_positives)

# %%
len(predicted)
# Out:
# 308

# %%
for x in predicted[0]:
    if x < 0:
        print(x)
# Out:
# -22.4076884167931
# -58.564988730278
# -20.8840486867393
# -6.37676456271296
# -12.3555266156601

# %%
gain = predicted.sum()

# %%
(gain - len(predicted))/len(predicted)
# Out:
# 0    289.720024
# dtype: float64

# %%
sandp_gain = sandp['percent_return_on_investment'].sum()

# %%
(sandp_gain - len(sandp['percent_return_on_investment']))/len(sandp['percent_return_on_investment'])
# Out:
# 228.6078093352651

# %%
# import pickle
# # Save the trained model as a pickle string.
# saved_model = pickle.dumps(classifier)

# %%
# saved_model

# %%
# # Load the pickled model
# clf_from_pickle = pickle.loads(saved_model)

# # Use the loaded pickled model to make predictions
# predictions = clf_from_pickle.predict(X)

# pd.DataFrame({'Prediction': predictions.ravel(), 'Actual': X}).head()
